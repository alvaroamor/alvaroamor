# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroamor/alvaroamor/blob/master/tweets_visualization_py24-02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twarc
# Out:
# ...
#      |████████████████████████████████| 55 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 97 kB 4.0 MB/s
# ...
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34547 sha256=0b78d26bb78a0e5ab312b12ac2826705b93c15923c4647ad72d4eebf5d89aa23
#   Stored in directory: /root/.cache/pip/wheels/0d/c4/19/13d74440f2a571841db6b6e0a273694327498884dafb9cf978
# Successfully built configobj
# ...
#   Attempting uninstall: humanize
#     Found existing installation: humanize 0.5.1
#     Uninstalling humanize-0.5.1:
#       Successfully uninstalled humanize-0.5.1
# ...

# %%
import plotly.graph_objects as go
from twarc import Twarc2


client = Twarc2(bearer_token= 'AAAAAAAAAAAAAAAAAAAAADJ4YgEAAAAAFwk25e%2F81SqiGWgm1B%2FLJtlygjY%3DRKt05inoMkFCMzx4ABbRcRJvJMSP8bjXlIE1Kso0kxFj05nLL3')

query = input("Introduce la palabra deseada")
search_results = client.counts_all(query, granularity ='hour')
# search_results = client.counts_recent(query, granularity ='hour')
for page in search_results:

    data = page['data']
    break

day = []

tweet_counts = []

for d in data:
    day.append(d['start'][:40])
    tweet_counts.append(d['tweet_count'])

fig = go.Figure(data=[go.Bar(x=day, y=tweet_counts)])
fig.show()
# Out:
# Introduce la palabra deseadaRusia
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Nueva sección

# %%
users = client.followers(user= 2754746065,  tweet_fields='public_metrics')

for page2 in users:
    
    data= page2['data']
    break

print(data)
# Out:
# [{'description': '', 'profile_image_url': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'created_at': '2022-02-15T09:52:37.000Z', 'url': '', 'verified': False, 'id': '1493523597184352256', 'public_metrics': {'followers_count': 0, 'following_count': 1, 'tweet_count': 0, 'listed_count': 0}, 'protected': False, 'name': 'pablo', 'username': 'pablo11452716'}, {'description': '', 'profile_image_url': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'created_at': '2022-02-15T09:52:06.000Z', 'url': '', 'verified': False, 'id': '1493523445858148357', 'public_metrics': {'followers_count': 0, 'following_count': 6, 'tweet_count': 0, 'listed_count': 0}, 'protected': False, 'name': 'Cristiangvn', 'username': 'cristiangvn'}, {'description': '', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1450193052212109316/7lOEOM3Z_normal.png', 'created_at': '2021-10-18T20:12:21.000Z', 'url': '', 'verified': False, 'id': '145019292
# ...

# %%
# %%shell
# jupyter nbconvert --to html /content/tweets_visualization_py.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/tweets_visualization_py.ipynb to html
# [NbConvertApp] Writing 916012 bytes to /content/tweets_visualization_py.html
