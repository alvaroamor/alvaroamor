# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroamor/alvaroamor/blob/master/24-02Followusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "Vf0992ajFRP56yeYl0FkTF6LW"
consumer_secret = "Aagx3zo6PpUZGRddwFDkrIBOJcTMRmIgdVV2U4q8ZtsTBvUMWz"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
print(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=M4tfmgAAAAABVJzVAAABfxxUdbM
# What's the pin value? 4448175
# ('603047056-vKFIKvxSKuSW9czpDWmsjLXV0P1L2LR6wYfeNjgr',
#  '8RMIBEqg98QzQvmXTWwt3WRmrK0p2wmteJl6iyDmGuU7v')

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
me = api.me()
me.screen_name
# Out:
# 'AlvaroAmor4'

# %%
userp = api.get_user("AlvaroAmor4")

numbers = []

numbers.append(userp.followers_count)

# %%
print(userp.followers_count, userp.friends_count)
# Out:
# 571 275

# %%
my_new_friends = []
lista = []
listaordenada = []
user_friends = user.followers()
for friend in user_friends:
        print(friend.screen_name)
        lista.append(friend.screen_name)
        listaordenada = sorted(lista)
        print(listaordenada)
# Out:
# Laaau_mg
# ['Laaau_mg']
# Franciscomeroo
# ['Franciscomeroo', 'Laaau_mg']
# luis_schwarz_
# ['Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# Danieltgodoy
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# reacamcu
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_', 'reacamcu']
# _Olivacarmen
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# JuventudPinatar
# ['Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# DamiiEc23
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# MoleroJosemi
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# edutakone
# ...

# %%
lista2 = []
for user in tweepy.Cursor(api.followers, "AlvaroAmor4").items():
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))
print(lista2)
  #print(user.followers_count, user.screen_name)
# Out:
# Rate limit reached. Sleeping for: 196
# Rate limit reached. Sleeping for: 893
# ...

# %%
lista2 = []
for k in listaordenada:
  user = api.get_user(k)
  print(user.followers_count, user.friends_count, user.screen_name)
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))


print(lista2)
# Out:
# 267 269 CanovasJorge
# 19 208 DamiiEc23
# 172 177 Danieltgodoy
# 684 402 Franciscomeroo
# 255 324 JuventudPinatar
# 208 228 Laaau_mg
# 67 146 MoleroJosemi
# 35 60 PetrarCancioner
# 122 110 _Olivacarmen
# 55 49 adri__pg
# 66 138 alexcabmar991
# 10 170 blancanievesum8
# 1058 451 edutakone
# 689 375 ffaza96
# 280 373 iliaslamziraa
# 110 199 luciavalcarcel_
# 306 294 luis_schwarz_
# 977 388 mariosocrazy
# 706 814 narcisonfor
# 23 19 reacamcu
# [('CanovasJorge', 267), ('DamiiEc23', 19), ('Danieltgodoy', 172), ('Franciscomeroo', 684), ('JuventudPinatar', 255), ('Laaau_mg', 208), ('MoleroJosemi', 67), ('PetrarCancioner', 35), ('_Olivacarmen', 122), ('adri__pg', 55), ('alexcabmar991', 66), ('blancanievesum8', 10), ('edutakone', 1058), ('ffaza96', 689), ('iliaslamziraa', 280), ('luciavalcarcel_', 110), ('luis_schwarz_', 306), ('mariosocrazy', 977), ('narcisonfor', 706), ('reacamcu', 23)]

# %%
def imprimir(lista2):
    print("Followers y sus nombres")
    for x in range(len(lista2)):
        print(lista2[x][0],lista2[x][1])

def pais_maspoblacion(lista2):
    pos=0
    for x in range(1,len(lista2)):
        if lista2[x][1]>lista2[pos][1]:
            pos=x
    print("Persona con mas followers:",lista2[pos][0])

# %%
imprimir(lista2)
pais_maspoblacion(lista2)
# Out:
# Followers y sus nombres
# Eresgamercom 589
# nico_marin2000 150
# Sebas_moratalla 138
# jpmrtinez 238
# JoseluHiguain 474
# reacamcu 23
# carloscharlie98 138
# InigualableSone 343
# Dolores87498568 109
# Elena25__ 316
# Diana44527 18
# Pilar261098 453
# lidia51995945 21
# deliaperezz_ 542
# elensj018 530
# Cosmeticosesse1 2
# Inmaalvareez_ 48
# Alex_Corral07 409
# claracxs 647
# atorrecilla_10_ 111
# luiscofern 45
# elenaafrndz 260
# RUGEMurcia 815
# angelaggarcia_ 259
# merimart 878
# olgaavn 143
# rotulcast 18
# Teresanava122 270
# aliiciiaa_15 120
# Ramonet37280098 4
# nurialcaina 350
# Enrique__Valero 753
# albertopereezzz 210
# Teresii10 140
# meerymoyaa 182
# lolaherranz 861
# jimmy_leann 5
# Ruben56677682 48
# Renataeljuri 68
# marinams__ 325
# joseelu16 83
# alba_marinn 216
# rokki 398
# danijorquera8 119
# toustusmuerto 472
# violetapintor 127
# Fran_Cano_ 662
# paulabenitezzz_ 8380
# Mefui1234567 439
# Luigi21Plus10 4
# Miriam47352133 3
# LaRa_1369 248
# marioazc0 78
# ...

# %%
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")

        
      
        

        
def scrape(words, date_since, numtweet):



        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]

                listaordenada = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
                listaordenada.clear()
                listaordenada.append(ith_tweet)
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)

# %%
print("Enter Twitter HashTag to search for")
words = input()
print("Enter Date since The Tweets are required in yyyy-mm--dd")
date_since = input()
 
# number of tweets you want to extract in one run
numtweet = 100
scrape(words, date_since, numtweet)

print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# RealMadrid
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2022-01-08
#
# Tweet 1:
# Username:aleflemos96
# Description:Deus conhece tua estrutura
# sabe oq está fazendo
# mesmo que seja difícil não pare ele está vendo 🎶🙌
# #EuTenhoUmChamado !!!
# Location:
# Following Count:844
# Follower Count:990
# Total Tweets:49905
# Retweet Count:513
# Tweet Text:⚽ @Benzema ❤️ GOLES
# #RealFootball https://t.co/27aIh4jZpP
# Hashtags Used:['RealFootball']
#
# Tweet 2:
# Username:LilEric212
# Description:my attitude is new york i dont give a fuck , get @ me
# Location:new york , new york
# Following Count:848
# Follower Count:857
# Total Tweets:45860
# Retweet Count:330
# Tweet Text:🤔 ¿Qué @Benzema te sientes hoy?
#
# 1️⃣ 😘
# 2️⃣ 💪
# 3️⃣ 🥳
# 4️⃣ 🤹‍♂️ https://t.co/7WKSCVxCq5
# Hashtags Used:[]
#
# Tweet 3:
# Username:shevaunavolta
# Description:Milanista, innamorato del calcio e di tutto ciò che lo riguarda.
# Ho pianto quando Andriy è andato via.
# ...

# %%
def Sort(listaordenada):
    l = len(listaordenada)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (listaordenada[j][1] > listaordenada[j + 1][1]):
                tempo = listaordenada[j]
                listaordenada[j]= listaordenada[j + 1]
                listaordenada[j + 1]= tempo
    return listaordenada

print(Sort(listaordenada))
# Out:
# [['Joritas2323', '', 'San Diego, CA', 40, 1, 3, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['jacobjppersson', '', '', 80, 46, 808, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['byronnn___', '', 'Los Angeles, CA', 63, 24, 2436, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['Messigician7', '', '', 106, 74, 41625, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['destrovenator', '', '', 1836, 71, 18376, 22, '🦕New paper on Late Jurassic ornithischians of Spain by Sánchez-Fenollosa et al. (2021) "Tracing Late #Jurassic ornithopod diversity in the eastern Iberian Peninsula: Camptosaurus‑like postcranial remains from #Alpuente (#Valencia, #Spain)" #Paleontology\nhttps://t.co/BxAmquWyc6 https://t.co/pm6fogXqv0', ['Jurassic']], ['zuev2222', '', '', 172, 127, 89782, 1, 'Who was your favourite in the brilliant Valencia si
# ...

# %%
def Sort(listaordenada):
  
    # reverse = None (Sorts in Ascending order)
    # key is set to sort using second element of 
    # sublist lambda has been used
    listaordenada.sort(key = lambda x: x[6], reverse=True)
    return listaordenada



print(Sort(listaordenada))
# Out:
# [['Joritas2323', '', 'San Diego, CA', 40, 1, 3, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['jacobjppersson', '', '', 80, 46, 808, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['byronnn___', '', 'Los Angeles, CA', 63, 24, 2436, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['Messigician7', '', '', 106, 74, 41625, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['MohBose', '#LM7', 'Home', 709, 431, 5667, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['D1EG0_LM10', "#Maradona #Messi #Laliga #Barca #EPL #Arsenal #SerieA #ACMilan #Bundesliga #Bayern #Ligue1 #NBA #Lakers #Kobe 🗣📢#Blmtoo #FreePalestine #FIFA 🥅 ⚽️`'؛،..💥🏃🏽", '🌎', 126, 3, 216, 329, 'Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH', []], ['wwatse', '#blacklivesmatter\n#teamGhana\n别理他们🏳
# ...

# %%
# %%shell
# jupyter nbconvert --to html /content/5_Follow_Users.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/5_Follow_Users.ipynb to html
# [NbConvertApp] Writing 433735 bytes to /content/5_Follow_Users.html
