# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroamor/alvaroamor/blob/master/PrimerospasosFollowersTwitter3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (0.8.9)

# %%
consumer_key = "Vf0992ajFRP56yeYl0FkTF6LW"
consumer_secret = "Aagx3zo6PpUZGRddwFDkrIBOJcTMRmIgdVV2U4q8ZtsTBvUMWz"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
print(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=BV6jYQAAAAABVJzVAAABfk4QXwE
# What's the pin value? 9866161
# ('603047056-vKFIKvxSKuSW9czpDWmsjLXV0P1L2LR6wYfeNjgr',
#  '8RMIBEqg98QzQvmXTWwt3WRmrK0p2wmteJl6iyDmGuU7v')

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
me = api.me()
me.screen_name
# Out:
# 'AlvaroAmor4'

# %%
userp = api.get_user("AlvaroAmor4")

numbers = []

numbers.append(userp.followers_count)

# %%
print(userp.followers_count, userp.friends_count)
# Out:
# 571 275

# %%
my_new_friends = []
lista = []
listaordenada = []
user_friends = user.followers()
for friend in user_friends:
        print(friend.screen_name)
        lista.append(friend.screen_name)
        listaordenada = sorted(lista)
        print(listaordenada)
# Out:
# Laaau_mg
# ['Laaau_mg']
# Franciscomeroo
# ['Franciscomeroo', 'Laaau_mg']
# luis_schwarz_
# ['Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# Danieltgodoy
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# reacamcu
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_', 'reacamcu']
# _Olivacarmen
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# JuventudPinatar
# ['Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# DamiiEc23
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# MoleroJosemi
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# edutakone
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'edutakone', 'luis_schwarz_', 'reacamcu']
# adri__pg
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'luis_schwarz_', 'reacamcu']
# mariosocrazy
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# iliaslamziraa
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# luciavalcarcel_
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# CanovasJorge
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# blancanievesum8
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# narcisonfor
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# PetrarCancioner
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# ffaza96
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'ffaza96', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# alexcabmar991
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'alexcabmar991', 'blancanievesum8', 'edutakone', 'ffaza96', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']

# %%
lista2 = []
for user in tweepy.Cursor(api.followers, "AlvaroAmor4").items():
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))
print(lista2)
  #print(user.followers_count, user.screen_name)
# Out:
# Rate limit reached. Sleeping for: 196
# Rate limit reached. Sleeping for: 893
# [('Eresgamercom', 589), ('nico_marin2000', 150), ('Sebas_moratalla', 138), ('jpmrtinez', 238), ('JoseluHiguain', 474), ('reacamcu', 23), ('carloscharlie98', 138), ('InigualableSone', 343), ('Dolores87498568', 109), ('Elena25__', 316), ('Diana44527', 18), ('Pilar261098', 453), ('lidia51995945', 21), ('deliaperezz_', 542), ('elensj018', 530), ('Cosmeticosesse1', 2), ('Inmaalvareez_', 48), ('Alex_Corral07', 409), ('claracxs', 647), ('atorrecilla_10_', 111), ('luiscofern', 45), ('elenaafrndz', 260), ('RUGEMurcia', 815), ('angelaggarcia_', 259), ('merimart', 878), ('olgaavn', 143), ('rotulcast', 18), ('Teresanava122', 270), ('aliiciiaa_15', 120), ('Ramonet37280098', 4), ('nurialcaina', 350), ('Enrique__Valero', 753), ('albertopereezzz', 210), ('Teresii10', 140), ('meerymoyaa', 182), ('lolaherranz', 861), ('jimmy_leann', 5), ('Ruben56677682', 48), ('Renataeljuri', 68), ('marinams__', 325), ('joseelu16', 83), ('alba_marinn', 216), ('rokki', 398), ('danijorquera8', 119), ('toustusmuerto', 472), ('violetapintor', 127), ('Fran_Cano_', 662), ('paulabenitezzz_', 8380), ('Mefui1234567', 439), ('Luigi21Plus10', 4), ('Miriam47352133', 3), ('LaRa_1369', 248), ('marioazc0', 78), ('UCAM', 37327), ('Gravesen_1', 104522), ('legenwario', 149), ('10Antoniorubio', 196), ('celdran_marina', 71), ('23Mariajr', 106), ('SorteosGluup', 66449), ('EnPedagogas', 1), ('mathiasvera17', 3311), ('Carlos43523021', 2), ('diegomaper7', 151), ('sergiocayuela09', 323), ('Carras_10_', 213), ('FuenVilches', 278), ('cristina_1401', 262), ('raquel_cayuela', 294), ('PinkPantera45', 42), ('AsturianoDani', 69), ('MyoLattAung1', 39), ('only4the_brave_', 19), ('inforges', 3107), ('Paola54115195', 21), ('Noeliaq20', 19), ('guslpz5', 127), ('Leganes_CA', 1118), ('GameOfPhrases', 156), ('mobn14', 214), ('anaalvarezz78', 4), ('angelosilva1999', 3), ('Biri525v', 295), ('desconectaoff', 7), ('AgustinLopezL19', 13), ('Pepe01sa', 470), ('DesguaceParis', 2132), ('RAPDEL90', 29), ('barcelo_ramirez', 2), ('UCAMMurciaVAVEL', 641), ('raqueelorenzo20', 299), ('KitHaringtonism', 491), ('sergiooo_aa', 212), ('Marialopezlop26', 115), ('ManolitoCruck', 8), ('JuanAnt11393525', 0), ('Magia_De_Futbol', 27146), ('Josescamez72', 22), ('josescamez', 33), ('LENVAYrap', 145), ('PabloPyconety', 15), ('PLluste', 4), ('chupi_01', 385), ('chupi_9', 52), ('Loolaasnchzz', 31), ('pimi_perez95', 12), ('ApolloAgencia', 12168), ('Amrsale91785512', 115), ('makingmoney471', 8), ('Pepa05942772', 2), ('Carliu13', 514), ('AutosMerinoSL', 158), ('PatriciaRuizGo8', 28), ('lokakao1', 137), ('mariocabelloo', 16), ('carlos_vacas_10', 18), ('maariagimenezz', 175), ('FBPicksFree', 2142), ('Marioazc00', 54), ('sebascarrasco13', 317), ('gosi7madridista', 198), ('pablo_misi', 14), ('rodrigoespin9', 276), ('FBCjuvenil', 51), ('davidabril99', 12), ('luciapiconn', 109), ('MariaEspin9', 363), ('marttaxxii', 212), ('fjazorin88', 137), ('Desordensexual', 21), ('annaasola', 539), ('CristinaOlivaG2', 6), ('eleniita_1999', 26), ('Andreallorent06', 10), ('milagro20910048', 9), ('trulynoted', 142), ('porrilla20', 128), ('Cristin05240978', 5), ('creacionesmagi', 776), ('angiezr21', 29), ('runnawaywithhme', 14), ('paquita_morote', 3), ('PaquitaTorra', 9), ('TakeMe2WendysDO', 2761), ('carlitos_10v', 25), ('alberto54321611', 2), ('africagarciaaa', 331), ('22_saritaa', 9), ('tufuturoesagua', 58), ('aroagm9', 273), ('diferente99', 211), ('6c32ae10ac2a46b', 12), ('buenapsicologia', 6616), ('jesuscfernandez', 55), ('esp_patria', 409), ('Carmen_re16', 39), ('ncgcia', 446), ('Miguelaito99', 188), ('EDMagBlog', 906), ('tomasbarsa99', 486), ('diegoMA_99', 223), ('Djpedroalvarez', 0), ('ApuntasT', 75), ('wampaspain', 106), ('angelasnxz', 288), ('andresnv99', 107), ('mariaangel_7', 72), ('antoniodp160580', 31), ('AlquipirJuvenil', 26), ('alejandrogd836', 128), ('albertocanara', 154), ('cristiansurki28', 36), ('ASummerStory_Md', 599), ('jjbus99', 696), ('paularobles27', 252), ('albertosr10', 127), ('awiznerg84', 114), ('RH_19_11_99', 24), ('mariap_180 ...

# %%
lista2 = []
for k in listaordenada:
  user = api.get_user(k)
  print(user.followers_count, user.friends_count, user.screen_name)
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))


print(lista2)
# Out:
# 267 269 CanovasJorge
# 19 208 DamiiEc23
# 172 177 Danieltgodoy
# 684 402 Franciscomeroo
# 255 324 JuventudPinatar
# 208 228 Laaau_mg
# 67 146 MoleroJosemi
# 35 60 PetrarCancioner
# 122 110 _Olivacarmen
# 55 49 adri__pg
# 66 138 alexcabmar991
# 10 170 blancanievesum8
# 1058 451 edutakone
# 689 375 ffaza96
# 280 373 iliaslamziraa
# 110 199 luciavalcarcel_
# 306 294 luis_schwarz_
# 977 388 mariosocrazy
# 706 814 narcisonfor
# 23 19 reacamcu
# [('CanovasJorge', 267), ('DamiiEc23', 19), ('Danieltgodoy', 172), ('Franciscomeroo', 684), ('JuventudPinatar', 255), ('Laaau_mg', 208), ('MoleroJosemi', 67), ('PetrarCancioner', 35), ('_Olivacarmen', 122), ('adri__pg', 55), ('alexcabmar991', 66), ('blancanievesum8', 10), ('edutakone', 1058), ('ffaza96', 689), ('iliaslamziraa', 280), ('luciavalcarcel_', 110), ('luis_schwarz_', 306), ('mariosocrazy', 977), ('narcisonfor', 706), ('reacamcu', 23)]

# %%
def imprimir(lista2):
    print("Followers y sus nombres")
    for x in range(len(lista2)):
        print(lista2[x][0],lista2[x][1])

def pais_maspoblacion(lista2):
    pos=0
    for x in range(1,len(lista2)):
        if lista2[x][1]>lista2[pos][1]:
            pos=x
    print("Persona con mas followers:",lista2[pos][0])

# %%
imprimir(lista2)
pais_maspoblacion(lista2)
# Out:
# Followers y sus nombres
# Eresgamercom 589
# nico_marin2000 150
# Sebas_moratalla 138
# jpmrtinez 238
# JoseluHiguain 474
# reacamcu 23
# carloscharlie98 138
# InigualableSone 343
# Dolores87498568 109
# Elena25__ 316
# Diana44527 18
# Pilar261098 453
# lidia51995945 21
# deliaperezz_ 542
# elensj018 530
# Cosmeticosesse1 2
# Inmaalvareez_ 48
# Alex_Corral07 409
# claracxs 647
# atorrecilla_10_ 111
# luiscofern 45
# elenaafrndz 260
# RUGEMurcia 815
# angelaggarcia_ 259
# merimart 878
# olgaavn 143
# rotulcast 18
# Teresanava122 270
# aliiciiaa_15 120
# Ramonet37280098 4
# nurialcaina 350
# Enrique__Valero 753
# albertopereezzz 210
# Teresii10 140
# meerymoyaa 182
# lolaherranz 861
# jimmy_leann 5
# Ruben56677682 48
# Renataeljuri 68
# marinams__ 325
# joseelu16 83
# alba_marinn 216
# rokki 398
# danijorquera8 119
# toustusmuerto 472
# violetapintor 127
# Fran_Cano_ 662
# paulabenitezzz_ 8380
# Mefui1234567 439
# Luigi21Plus10 4
# Miriam47352133 3
# LaRa_1369 248
# marioazc0 78
# UCAM 37327
# Gravesen_1 104522
# legenwario 149
# 10Antoniorubio 196
# celdran_marina 71
# 23Mariajr 106
# SorteosGluup 66449
# EnPedagogas 1
# mathiasvera17 3311
# Carlos43523021 2
# diegomaper7 151
# sergiocayuela09 323
# Carras_10_ 213
# FuenVilches 278
# cristina_1401 262
# raquel_cayuela 294
# PinkPantera45 42
# AsturianoDani 69
# MyoLattAung1 39
# only4the_brave_ 19
# inforges 3107
# Paola54115195 21
# Noeliaq20 19
# guslpz5 127
# Leganes_CA 1118
# GameOfPhrases 156
# mobn14 214
# anaalvarezz78 4
# angelosilva1999 3
# Biri525v 295
# desconectaoff 7
# AgustinLopezL19 13
# Pepe01sa 470
# DesguaceParis 2132
# RAPDEL90 29
# barcelo_ramirez 2
# UCAMMurciaVAVEL 641
# raqueelorenzo20 299
# KitHaringtonism 491
# sergiooo_aa 212
# Marialopezlop26 115
# ManolitoCruck 8
# JuanAnt11393525 0
# Magia_De_Futbol 27146
# Josescamez72 22
# josescamez 33
# LENVAYrap 145
# PabloPyconety 15
# PLluste 4
# chupi_01 385
# chupi_9 52
# Loolaasnchzz 31
# pimi_perez95 12
# ApolloAgencia 12168
# Amrsale91785512 115
# makingmoney471 8
# Pepa05942772 2
# Carliu13 514
# AutosMerinoSL 158
# PatriciaRuizGo8 28
# lokakao1 137
# mariocabelloo 16
# carlos_vacas_10 18
# maariagimenezz 175
# FBPicksFree 2142
# Marioazc00 54
# sebascarrasco13 317
# gosi7madridista 198
# pablo_misi 14
# rodrigoespin9 276
# FBCjuvenil 51
# davidabril99 12
# luciapiconn 109
# MariaEspin9 363
# marttaxxii 212
# fjazorin88 137
# Desordensexual 21
# annaasola 539
# CristinaOlivaG2 6
# eleniita_1999 26
# Andreallorent06 10
# milagro20910048 9
# trulynoted 142
# porrilla20 128
# Cristin05240978 5
# creacionesmagi 776
# angiezr21 29
# runnawaywithhme 14
# paquita_morote 3
# PaquitaTorra 9
# TakeMe2WendysDO 2761
# carlitos_10v 25
# alberto54321611 2
# africagarciaaa 331
# 22_saritaa 9
# tufuturoesagua 58
# aroagm9 273
# diferente99 211
# 6c32ae10ac2a46b 12
# buenapsicologia 6616
# jesuscfernandez 55
# esp_patria 409
# Carmen_re16 39
# ncgcia 446
# Miguelaito99 188
# EDMagBlog 906
# tomasbarsa99 486
# diegoMA_99 223
# Djpedroalvarez 0
# ApuntasT 75
# wampaspain 106
# angelasnxz 288
# andresnv99 107
# mariaangel_7 72
# antoniodp160580 31
# AlquipirJuvenil 26
# alejandrogd836 128
# albertocanara 154
# cristiansurki28 36
# ASummerStory_Md 599
# jjbus99 696
# paularobles27 252
# albertosr10 127
# awiznerg84 114
# RH_19_11_99 24
# mariap_180202 708
# colladojocd1 144
# stonercum 381
# Ffhcvgh 72
# 15501pros 1781
# ijustfollow321 69
# Inspira79675042 478
# JuanJoseGuill14 4
# Javi_Carta1 765
# rosannalpz_ 562
# MarpePilar 5
# makysofii 16
# DJimenezzzz_ 210
# pa_sopar 21
# RANDALLANDERSO4 799
# CarmenSanchezDu 423
# 6_Pablo_9 1129
# claudia_10101 0
# crespicks 137
# iPaisajesEs 2100
# CaravacaEncuest 184
# ShishasDeModa 12194
# lauramorenilla_ 153
# marianiko_97 550
# serranotorres81 128
# FuturosCracksTV 9593
# alvaro16naranjo 608
# _inma123_ 72
# david05guerrero 405
# pobicanara 48
# bermejaito 151
# 991_mariajose 219
# Verdazos_es 614
# miryam_16700 40
# Mari22rojas 178
# javier_8_14 1
# mariah1139 303
# ArchivelFiestas 136
# oraval02 191
# lady_sandy94 207
# carmengarib99 119
# dominquefxp51 228
# DJ_Juanmi_WTF 290
# marina_celdran8 138
# mt22_maria 291
# belenamoor 628
# esmeral15254998 286
# pjnavarrete4 491
# alberto6cantero 105
# miguel_2732003 26
# Rrpplorca 388
# AnnaSanchzGea 601
# Sonialloret_11 122
# elennapolo 567
# rauliko7 304
# Dani_Ros10 52
# angelasnchlo 200
# mntsabril 474
# emiliete2001 34
# P_Retorno 277
# mariagonz_2000 272
# Aalex_241527 14
# WikiBorracheras 35
# belenmartinezl3 124
# RunningEnMurcia 226
# talianamayte22 46
# jeffpromotes 404
# LorenicaNavarro 664
# Spain_Under 4123
# yosoieljosete 2
# AnahiBR00 597
# mjgs_98 582
# _andreabernes 372
# ampaiesvega 69
# ErasJefferon 6
# NicolasMarin_10 506
# OrtegaRocio14 295
# Meroo112000 113
# VeraBianchi6 707
# Lucia10008 1059
# Leandro10_99 110
# JoseVic_Torres 319
# jabatocaravaca 158
# Isamodel99 552
# jonyxulo94 468
# Maria_gr04 372
# 43f360b58dcb47b 78
# rodrigoespin10 207
# PipaGozalbes 4816
# pCabEscandalo 306
# mariaferr1165 182
# AnimalSoundFica 38
# LaComparacion 110853
# MariaAbril_3 355
# carmen_9_ 154
# AllTheXperience 1881
# maria_nlpez 213
# CCEOdontolog 61
# NoroesteRioMula 1155
# ivanacorreas_9 329
# irenne99 269
# alejandro_MZGZ 25
# burguerciudadj 226
# enmabattu 872
# AnabelTudela 514
# edif7 191
# lauracorbalanS9 158
# albertocor12 79
# CaravacaFiesta 123
# MariCruzMontiel 297
# alexruizf10 377
# SergioCebolla5 85
# naicu123 145
# andrea_pr_10 659
# rocayu98 388
# nicugrecu38 22
# mayorking_3 288
# 2Andreu 643
# Mr_motivador 765
# grecu_nicu 30
# JJMotorSport 28
# aliciapozo21 340
# PaulaCaro20 269
# RuPeRR99 67
# mariacr286 497
# merasol3wixco 151
# carmenmaria_23 559
# lauralopezmart3 114
# Otra_Cosa0w0 0
# anakinty8 3
# esmeralda_ng23 110
# sergiocaamaque 491
# danifll03 313
# Lopez5Salva 722
# CaravacaCJ 143
# AAdri303 44
# ixiosmoixi 44677
# SonidoEDM 32956
# Marineeraa_ 838
# tlg94r 111
# Neassle 195
# AnamGazquez 498
# josephinenicol_ 187
# Jonathan_atlest 63
# mtcorreas7 501
# mariahonne 580
# marialopezlop08 187
# Paulaortuno 216
# maria_21piluka 522
# AliciaTorres_22 610
# elenaiborra23 465
# elenaortiz_99 393
# carmenmariia13 493
# MariinaFdez9 528
# 10TajMahal 83
# MaraAbril3 425
# MariaPuerta83 686
# magin_8 626
# PERIWES 228
# LuciaPicoon 620
# marrmrss 418
# josico_748 51
# Carmen_MariaMG 550
# Teresa_SM1 679
# mavisanchez22 196
# Maria22Rojas 434
# arqu_bizarra 135
# OsitoPerez 444
# Gines_Kopero 379
# miriam_robl 290
# GSJose8 375
# 14Ismaerobles 85
# MoyaRuizmoya 257
# HernaizAlba 1030
# antonioperezf97 50
# manucastipolo 168
# amnpz16 664
# jessica_megan12 48
# liguescaravaca 191
# Miriam_FL 536
# Elenamarin0 423
# Malmax5 366
# TipicoAquel 44
# cmlopezauguy 126
# alonso1528 41
# Paloma24_NV 931
# irenecaballos 582
# LauraReina99 732
# marinacj36 94
# dondrama46 30
# pgalvez12 263
# miripque 19
# Pikyjm 580
# mariiags17 284
# ErrGhetto 172
# Jaimesk8Romero 462
# IvanTorres_17 193
# MLPepito98 342
# carmenml_99 228
# samuelote1495 153
# Torrecilla52 459
# lourdes_tb99 595
# soniasszz 945
# PatriciaCeldran 403
# victoriamtnez13 294
# rubio_ruben 187
# Victoria_agudo 212
# picon_ap 260
# nataliamontanos 969
# rodriespin10 173
# ColladosAILD 1902
# Nuricastre 644
# leti1699 334
# anabel398 446
# Gines5Garcia 403
# Carmengaarciia 1063
# pedrohervas17 555
# mariagmay 321
# Mariia03_ 71
# ElenaMarin20 718
# Analove_13 261
# irenemt22 598
# mariags_17 75
# _tusonrisa01 1
# josemaarb 629
# AnabelTudelaL24 489
# sfglez_ 534
# lluviaponce138 231
# Laufg26 631
# ananavarro200 377
# rubiomt_ 841
# critian_perete 441
# Juliamarti98 457
# santos29mr 60
# LasDamas2014 94
# lasalcedo3 113
# clarasnxz 1000
# antonioabeiro_5 599
# Mariiaadelaamor 455
# Angelotta_28 486
# AnaGarcia1616 200
# mariasalinas98 493
# maginesko 152
# doriboluda 356
# cristianLop_80 39
# amparo_2610 498
# Angela_NV 438
# 8IsabelMaria8 794
# Alba9721 646
# MariaJoseLM9 593
# mariinatoral_98 712
# isabescavy 217
# MirandaIM25 534
# JesusGG_99 207
# LetiiSanchez98 389
# CarmenMJorquera 765
# pedrofm98 338
# Charly_797 552
# LuciaBoluda 789
# AnaMarinSanchez 534
# Carmencampos98 365
# Alberto_2209 474
# marta_romera 461
# elenaflive 441
# fer01786526 333
# elenaroca99 631
# Anaa_Capaarroos 526
# taamaraa_14 675
# Lauragp_99 710
# EstherLlamas2 663
# SrJuanPedro 162
# manuelolo66 168
# cristia23318358 120
# Deme10NBA 143
# FrasesChulas25 219
# mariaSF99 904
# Amantesdelamsic 207
# Martuchi7152 541
# chulesjesusc 251
# 27_LauraN 165
# Helen_rma 364
# pedrodavid_1996 400
# oscargonza96 121
# Raulgm0909 187
# sariita_smp 313
# JoseMarcos02 651
# davidmm99 94
# estefany_tuloca 267
# Nati_Munuera 456
# felipe_916 657
# chemari_4 488
# alesceldran 96
# MariaCorrales16 493
# inthemadnesss 3146
# isabelsanxez 338
# Rubia_65 117
# aaroncelb 590
# andreabril1999 680
# alvaroalarte 200
# AndreaRomerico 133
# eliagr59 632
# adriaN_Rdez26 154
# juanto_15 456
# pilarrvillo 293
# VaroFcb 698
# troyano349 528
# Rosiitadeltoro 750
# MariaPeVillo 479
# pablof50 487
# Alberto_Rubio9 229
# EmilioMsjs_5 870
# pedricola2000 48
# Sandra_GG18 236
# juanma9_9 425
# andreaRomS 68
# adrigd_69 5
# diimassanchez 572
# alicialopezmuoz 564
# elenaAV_99 240
# PalomaRigabert 539
# andrea_lude 529
# mariaa_naavarro 126
# caparrs_ana 75
# mariasalcedo_8 103
# alvatrios 347
# Rajao_5 701
# JulianR5 282
# MoroteAlba 507
# antoniosola98 309
# albamartinezz_9 321
# danielazorin7 781
# _luiscamacho75 481
# Patrigarciamel 504
# AlejandroDinten 850
# andrearomel10 590
# Ivanfeg1998 435
# JoseSanchez2559 419
# adrilzlz 443
# Sergioelespanol 510
# marinarbortz_ 662
# andrea_PG08 956
# ChechuMrtnz98 471
# dani13sanchez 96
# Torralba6 270
# zaplana8 148
# Pedro_J_MG 263
# adri_gd69 676
# AnaRigabert_ 250
# bataneroantonio 413
# ValySanchez97 740
# jesuspepi15 260
# Torralba96 430
# emiliojose_9 284
# juananMARIN3 422
# GL_Josema 290
# joseaportero1 332
# cristianperete 186
# PedroAlarcon25 839
# carliticos99 460
# TeresadeFreesaa 335
# Derti14 686
# AdriSanchezC5 185
# A_DavidFdez10 532
# rubensanchezlop 410
# 13_sweet13 404
# jose5sanchez 517
# rafa_pucelaa 592
# Futbol_Actual_ 105
# mariatj97 543
# Patrii990 628
# YaryDavid 276
# manolog64752622 445
# Mayorking10 747
# xiki_11 396
# MrosagmC 119
# AngelGM9 752
# loles_99 434
# Alberto_2606 254
# albasanchez990 672
# mariiagb14 402
# andreagl_99 532
# ana_gimenez_99 379
# MrCarlosAndres 708
# anamariapuerta_ 307
# JuanAnt_Fem 268
# 99Morote 241
# PiedadGuillen99 270
# TariqMay 0
# Alber_MaBer 437
# LMariadelao 556
# alberto_gomez88 559
# Mromar5432 143
# MiguiGameplays 290
# Persona con mas followers: LaComparacion

# %%
from tabulate import tabulate
listaordenada = []
coordinates = '19.402833,-99.141051,50mi'
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")

        

        
def scrape(words, date_since, numtweet):



        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search, 
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets: 
          if tweet.user.verified :
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']


              
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
                
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]

                
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
                
                listaordenada.append(ith_tweet)
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)

# %%
print("Enter Twitter HashTag to search for")
words = input()
print("Enter Date since The Tweets are required in yyyy-mm--dd")
date_since = input()
 
# number of tweets you want to extract in one run
numtweet = 100
scrape(words, date_since, numtweet)

print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# #RealMadrid
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2021-12-01
#
# Tweet 1:
# Username:SportsMole
# Description:The latest breaking sports news and live coverage around the clock.
# Location:Follow teams ➜ bit.ly/SM-Lists
# Following Count:681
# Follower Count:40080
# Total Tweets:36989
# Retweet Count:1
# Tweet Text:What an evening of football we have in store 🤩
#
# 7pm: Barcelona vs. Real Madrid
# 7.45pm: Tottenham vs. Chelsea
# 7.45pm: West Ham vs. Norwich
# 8pm: Inter Milan vs. Juventus
#
# #elclasico #eflcup #carabaocup #premierleague #barcelona #realmadrid #spurs #chelsea https://t.co/LlaewK6dde
# Hashtags Used:['elclasico', 'eflcup', 'carabaocup', 'premierleague', 'barcelona', 'realmadrid', 'spurs', 'chelsea']
#
# Tweet 2:
# Username:ESPNPR
# Description:ESPN press releases & news.
# For behind-the-scenes stories, visit ESPN's blog https://t.co/4PZbAKdlYE
# Location:Bristol, CT
# Following Count:323
# Follower Count:125472
# Total Tweets:18371
# Retweet Count:8
# Tweet Text:Wednesday, #FCBarcelona &amp; #RealMadrid face-off in the second #ElClasico of the '21-'22 Spanish soccer season in Supercopa de España
#
# 🎙 English | @RaeComm, Stewart Robson
# 🎙 Spanish | @fernandopalomo, @ESPNMarioKempes
#
# ⚽️ 2p ET | ESPN, @ESPNDeportes, @ESPNPlus https://t.co/eN19QHL1tc
# Hashtags Used:['FCBarcelona', 'RealMadrid', 'ElClasico']
#
# Tweet 3:
# Username:CICSaudi
# Description:The Center for International Communication is a central source of info on the changing face of #SaudiArabia.
# Location:
# Following Count:3
# Follower Count:105238
# Total Tweets:3881
# Retweet Count:1
# Tweet Text:#Barcelona, #RealMadrid, #AtleticoMadrid, and #AthleticBilbao at King Fahd International Stadium this week. Saudi Arabia will host the #SpanishSuperCub for the second time, starting today! https://t.co/YEgQ4X5NmJ
# Hashtags Used:['Barcelona', 'RealMadrid', 'AtleticoMadrid', 'AthleticBilbao', 'SpanishSuperCub']
#
# Tweet 4:
# Username:twelfthman_ofcl
# Description:A fantasy football app made by the fans, for the fans. Join our Discord Server: https://t.co/xsyDG4vu0T
# Location:India
# Following Count:188
# Follower Count:8717
# Total Tweets:5231
# Retweet Count:0
# Tweet Text:🚨THIS IS NOT A DRILL🚨
#
# Drop everything you're doing, because it's almost #ElClasico time! 🔥🔥🔥🔥
#
# First one of 2022 and excitement levels are maxed out!! Made your Twelfth Man team yet? ➡️ https://t.co/Lpd3fATlUH
#
# #Barcelona #RealMadrid #TwelfthMan #Football #Supercopa https://t.co/O54DiGTlie
# Hashtags Used:['ElClasico', 'Barcelona', 'RealMadrid', 'TwelfthMan', 'Football', 'Supercopa']
#
# Tweet 5:
# Username:ZeeNewsEnglish
# Description:https://t.co/lEQgCckyM5 brings you the latest news with 360 degree coverage across genres
#
# Instagram: https://t.co/CZ1MfoF4fc
# Download App - https://t.co/lRdBWwdpjp
# Location:India
# Following Count:32
# Follower Count:5538323
# Total Tweets:409280
# Retweet Count:0
# Tweet Text:Here is where and when you can watch #ElClasico #SpanishSuperCup semi-finals between #Barcelona and #RealMadrid in India
#
# #BarcelonaRealMadrid @FCBarcelona @realmadrid
#
# https://t.co/JNdnXW6tQo
# Hashtags Used:['ElClasico', 'SpanishSuperCup', 'Barcelona', 'RealMadrid', 'BarcelonaRealMadrid']
# Scraping has completed!

# %%
def Sort(listaordenada):
  
    # reverse = None (Sorts in Ascending order)
    # key is set to sort using second element of 
    # sublist lambda has been used
    listaordenada.sort(key = lambda x: x[6], reverse=True)
    return listaordenada



print(tabulate(Sort(listaordenada)))
# Out:
# ---------------  ------------------------------------------------------------------------------------------------------------------------------------------------------  ------------------------------  ---  -------  ------  -  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------------------------------------------------------------------------------------------------
# ESPNPR           ESPN press releases & news.                                                                                                                             Bristol, CT                     323   125467   18371  8  Wednesday, #FCBarcelona &amp; #RealMadrid face-off in the second #ElClasico of the '21-'22 Spanish soccer season in Supercopa de España                                                                               ['FCBarcelona', 'RealMadrid', 'ElClasico']
#                  For behind-the-scenes stories, visit ESPN's blog https://t.co/4PZbAKdlYE
#                                                                                                                                                                                                                                   🎙 English | @RaeComm, Stewart Robson
#                                                                                                                                                                                                                                   🎙 Spanish | @fernandopalomo, @ESPNMarioKempes
#
#                                                                                                                                                                                                                                   ⚽️ 2p ET | ESPN, @ESPNDeportes, @ESPNPlus https://t.co/eN19QHL1tc
# SportsMole       The latest breaking sports news and live coverage around the clock.                                                                                     Follow teams ➜ bit.ly/SM-Lists  681    40080   36989  1  What an evening of football we have in store 🤩                                                                                                                                                                       ['elclasico', 'eflcup', 'carabaocup', 'premierleague', 'barcelona', 'realmadrid', 'spurs', 'chelsea']
#
#                                                                                                                                                                                                                                   7pm: Barcelona vs. Real Madrid
#                                                                                                                                                                                                                                   7.45pm: Tottenham vs. Chelsea
#                                                                                                                                                                                                                                   7.45pm: West Ham vs. Norwich
#                                                                                                                                                                                                                                   8pm: Inter Milan vs. Juventus
#
#                                                                                                                                                                                                                                   #elclasico #eflcup #carabaocup #premierleague #barcelona #realmadrid #spurs #chelsea https://t.co/LlaewK6dde
# CICSaudi         The Center for International Communication is a central source of info on the changing face of #SaudiArabia.                                                                              3   105238    3881  1  #Barcelona, #RealMadrid, #AtleticoMadrid, and #AthleticBilbao at King Fahd International Stadium this week. Saudi Arabia will host the #SpanishSuperCub for the second time, starting today! https://t.co/YEgQ4X5NmJ  ['Barcelona', 'RealMadrid', 'AtleticoMadrid', 'AthleticBilbao', 'SpanishSuperCub']
# twelfthman_ofcl  A fantasy football app made by the fans, for the fans. Join our Discord Server: https://t.co/xsyDG4vu0T                                                 India                           188     8717    5231  0  🚨THIS IS NOT A DRILL🚨                                                                                                                                                                                               ['ElClasico', 'Barcelona', 'RealMadrid', 'TwelfthMan', 'Football', 'Supercopa']
#
#                                                                                                                                                                                                                                   Drop everything you're doing, because it's almost #ElClasico time! 🔥🔥🔥🔥
#
#                                                                                                                                                                                                                                   First one of 2022 and excitement levels are maxed out!! Made your Twelfth Man team yet? ➡️ https://t.co/Lpd3fATlUH
#
#                                                                                                                                                                                                                                   #Barcelona #RealMadrid #TwelfthMan #Football #Supercopa https://t.co/O54DiGTlie
# ZeeNewsEnglish   https://t.co/lEQgCckyM5 brings you the latest news with 360 degree coverage across genres                                                               India                            32  5538318  409280  0  Here is where and when you can watch #ElClasico #SpanishSuperCup semi-finals between #Barcelona and #RealMadrid in India                                                                                              ['ElClasico', 'SpanishSuperCup', 'Barcelona', 'RealMadrid', 'BarcelonaRealMadrid']
#
#                  Instagram: https://t.co/CZ1MfoF4fc                                                                                                                                                                               #BarcelonaRealMadrid @FCBarcelona @realmadrid
#                  Download App - https://t.co/lRdBWwdpjp
#                                                                                                                                                                                                                                   https://t.co/JNdnXW6tQo
# latestly         https://t.co/UVDtERUJlr focuses on the What, When, Who and How of a trending story, and helps readers with analyses that go beyond the domain of news.  Mumbai, India                   348    72142  229387  0  Barcelona vs Real Madrid, Spanish Super Cup 2022 Live Streaming Online: Get Free Telecast Details of El Clasico Football Match in Supercopa De Espana Semifinal on TV With Time in India                              ['BarcelonaRealMadrid', 'Barcelona', 'RealMadrid', 'SpanishSuperCup']
#
#                                                                                                                                                                                                                                   #BarcelonaRealMadrid #Barcelona #RealMadrid #SpanishSuperCup
#
#                                                                                                                                                                                                                                   https://t.co/sgyZXG2G6Z
# ---------------  ------------------------------------------------------------------------------------------------------------------------------------------------------  ------------------------------  ---  -------  ------  -  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------------------------------------------------------------------------------------------------
