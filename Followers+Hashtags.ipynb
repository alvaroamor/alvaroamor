# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroamor/alvaroamor/blob/master/Followers%2BHashtags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "Vf0992ajFRP56yeYl0FkTF6LW"
consumer_secret = "Aagx3zo6PpUZGRddwFDkrIBOJcTMRmIgdVV2U4q8ZtsTBvUMWz"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
print(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=iXCsLAAAAAABVJzVAAABfj9i56Y
# What's the pin value? 5921875
# ('603047056-vKFIKvxSKuSW9czpDWmsjLXV0P1L2LR6wYfeNjgr',
#  '8RMIBEqg98QzQvmXTWwt3WRmrK0p2wmteJl6iyDmGuU7v')

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
me = api.me()
me.screen_name
# Out:
# 'AlvaroAmor4'

# %%
userp = api.get_user("AlvaroAmor4")

numbers = []

numbers.append(userp.followers_count)

# %%
print(userp.followers_count, userp.friends_count)
# Out:
# 571 275

# %%
my_new_friends = []
lista = []
listaordenada = []
user_friends = user.followers()
for friend in user_friends:
        print(friend.screen_name)
        lista.append(friend.screen_name)
        listaordenada = sorted(lista)
        print(listaordenada)
# Out:
# Laaau_mg
# ['Laaau_mg']
# Franciscomeroo
# ['Franciscomeroo', 'Laaau_mg']
# luis_schwarz_
# ['Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# Danieltgodoy
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_']
# reacamcu
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', 'luis_schwarz_', 'reacamcu']
# _Olivacarmen
# ['Danieltgodoy', 'Franciscomeroo', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# JuventudPinatar
# ['Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# DamiiEc23
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# MoleroJosemi
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'luis_schwarz_', 'reacamcu']
# edutakone
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'edutakone', 'luis_schwarz_', 'reacamcu']
# adri__pg
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'luis_schwarz_', 'reacamcu']
# mariosocrazy
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# iliaslamziraa
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# luciavalcarcel_
# ['DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# CanovasJorge
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# blancanievesum8
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'reacamcu']
# narcisonfor
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# PetrarCancioner
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# ffaza96
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'blancanievesum8', 'edutakone', 'ffaza96', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']
# alexcabmar991
# ['CanovasJorge', 'DamiiEc23', 'Danieltgodoy', 'Franciscomeroo', 'JuventudPinatar', 'Laaau_mg', 'MoleroJosemi', 'PetrarCancioner', '_Olivacarmen', 'adri__pg', 'alexcabmar991', 'blancanievesum8', 'edutakone', 'ffaza96', 'iliaslamziraa', 'luciavalcarcel_', 'luis_schwarz_', 'mariosocrazy', 'narcisonfor', 'reacamcu']

# %%
lista2 = []
for user in tweepy.Cursor(api.followers, "AlvaroAmor4").items():
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))
print(lista2)
  #print(user.followers_count, user.screen_name)
# Out:
# Rate limit reached. Sleeping for: 196
# Rate limit reached. Sleeping for: 893
# [('Eresgamercom', 589), ('nico_marin2000', 150), ('Sebas_moratalla', 138), ('jpmrtinez', 238), ('JoseluHiguain', 474), ('reacamcu', 23), ('carloscharlie98', 138), ('InigualableSone', 343), ('Dolores87498568', 109), ('Elena25__', 316), ('Diana44527', 18), ('Pilar261098', 453), ('lidia51995945', 21), ('deliaperezz_', 542), ('elensj018', 530), ('Cosmeticosesse1', 2), ('Inmaalvareez_', 48), ('Alex_Corral07', 409), ('claracxs', 647), ('atorrecilla_10_', 111), ('luiscofern', 45), ('elenaafrndz', 260), ('RUGEMurcia', 815), ('angelaggarcia_', 259), ('merimart', 878), ('olgaavn', 143), ('rotulcast', 18), ('Teresanava122', 270), ('aliiciiaa_15', 120), ('Ramonet37280098', 4), ('nurialcaina', 350), ('Enrique__Valero', 753), ('albertopereezzz', 210), ('Teresii10', 140), ('meerymoyaa', 182), ('lolaherranz', 861), ('jimmy_leann', 5), ('Ruben56677682', 48), ('Renataeljuri', 68), ('marinams__', 325), ('joseelu16', 83), ('alba_marinn', 216), ('rokki', 398), ('danijorquera8', 119), ('toustusmuerto', 472), ('violetapintor', 127), ('Fran_Cano_', 662), ('paulabenitezzz_', 8380), ('Mefui1234567', 439), ('Luigi21Plus10', 4), ('Miriam47352133', 3), ('LaRa_1369', 248), ('marioazc0', 78), ('UCAM', 37327), ('Gravesen_1', 104522), ('legenwario', 149), ('10Antoniorubio', 196), ('celdran_marina', 71), ('23Mariajr', 106), ('SorteosGluup', 66449), ('EnPedagogas', 1), ('mathiasvera17', 3311), ('Carlos43523021', 2), ('diegomaper7', 151), ('sergiocayuela09', 323), ('Carras_10_', 213), ('FuenVilches', 278), ('cristina_1401', 262), ('raquel_cayuela', 294), ('PinkPantera45', 42), ('AsturianoDani', 69), ('MyoLattAung1', 39), ('only4the_brave_', 19), ('inforges', 3107), ('Paola54115195', 21), ('Noeliaq20', 19), ('guslpz5', 127), ('Leganes_CA', 1118), ('GameOfPhrases', 156), ('mobn14', 214), ('anaalvarezz78', 4), ('angelosilva1999', 3), ('Biri525v', 295), ('desconectaoff', 7), ('AgustinLopezL19', 13), ('Pepe01sa', 470), ('DesguaceParis', 2132), ('RAPDEL90', 29), ('barcelo_ramirez', 2), ('UCAMMurciaVAVEL', 641), ('raqueelorenzo20', 299), ('KitHaringtonism', 491), ('sergiooo_aa', 212), ('Marialopezlop26', 115), ('ManolitoCruck', 8), ('JuanAnt11393525', 0), ('Magia_De_Futbol', 27146), ('Josescamez72', 22), ('josescamez', 33), ('LENVAYrap', 145), ('PabloPyconety', 15), ('PLluste', 4), ('chupi_01', 385), ('chupi_9', 52), ('Loolaasnchzz', 31), ('pimi_perez95', 12), ('ApolloAgencia', 12168), ('Amrsale91785512', 115), ('makingmoney471', 8), ('Pepa05942772', 2), ('Carliu13', 514), ('AutosMerinoSL', 158), ('PatriciaRuizGo8', 28), ('lokakao1', 137), ('mariocabelloo', 16), ('carlos_vacas_10', 18), ('maariagimenezz', 175), ('FBPicksFree', 2142), ('Marioazc00', 54), ('sebascarrasco13', 317), ('gosi7madridista', 198), ('pablo_misi', 14), ('rodrigoespin9', 276), ('FBCjuvenil', 51), ('davidabril99', 12), ('luciapiconn', 109), ('MariaEspin9', 363), ('marttaxxii', 212), ('fjazorin88', 137), ('Desordensexual', 21), ('annaasola', 539), ('CristinaOlivaG2', 6), ('eleniita_1999', 26), ('Andreallorent06', 10), ('milagro20910048', 9), ('trulynoted', 142), ('porrilla20', 128), ('Cristin05240978', 5), ('creacionesmagi', 776), ('angiezr21', 29), ('runnawaywithhme', 14), ('paquita_morote', 3), ('PaquitaTorra', 9), ('TakeMe2WendysDO', 2761), ('carlitos_10v', 25), ('alberto54321611', 2), ('africagarciaaa', 331), ('22_saritaa', 9), ('tufuturoesagua', 58), ('aroagm9', 273), ('diferente99', 211), ('6c32ae10ac2a46b', 12), ('buenapsicologia', 6616), ('jesuscfernandez', 55), ('esp_patria', 409), ('Carmen_re16', 39), ('ncgcia', 446), ('Miguelaito99', 188), ('EDMagBlog', 906), ('tomasbarsa99', 486), ('diegoMA_99', 223), ('Djpedroalvarez', 0), ('ApuntasT', 75), ('wampaspain', 106), ('angelasnxz', 288), ('andresnv99', 107), ('mariaangel_7', 72), ('antoniodp160580', 31), ('AlquipirJuvenil', 26), ('alejandrogd836', 128), ('albertocanara', 154), ('cristiansurki28', 36), ('ASummerStory_Md', 599), ('jjbus99', 696), ('paularobles27', 252), ('albertosr10', 127), ('awiznerg84', 114), ('RH_19_11_99', 24), ('mariap_180 ...

# %%
lista2 = []
for k in listaordenada:
  user = api.get_user(k)
  print(user.followers_count, user.friends_count, user.screen_name)
  followers = user.followers_count
  nombre = user.screen_name
  lista2.append((nombre,followers))


print(lista2)
# Out:
# 267 269 CanovasJorge
# 19 208 DamiiEc23
# 172 177 Danieltgodoy
# 684 402 Franciscomeroo
# 255 324 JuventudPinatar
# 208 228 Laaau_mg
# 67 146 MoleroJosemi
# 35 60 PetrarCancioner
# 122 110 _Olivacarmen
# 55 49 adri__pg
# 66 138 alexcabmar991
# 10 170 blancanievesum8
# 1058 451 edutakone
# 689 375 ffaza96
# 280 373 iliaslamziraa
# 110 199 luciavalcarcel_
# 306 294 luis_schwarz_
# 977 388 mariosocrazy
# 706 814 narcisonfor
# 23 19 reacamcu
# [('CanovasJorge', 267), ('DamiiEc23', 19), ('Danieltgodoy', 172), ('Franciscomeroo', 684), ('JuventudPinatar', 255), ('Laaau_mg', 208), ('MoleroJosemi', 67), ('PetrarCancioner', 35), ('_Olivacarmen', 122), ('adri__pg', 55), ('alexcabmar991', 66), ('blancanievesum8', 10), ('edutakone', 1058), ('ffaza96', 689), ('iliaslamziraa', 280), ('luciavalcarcel_', 110), ('luis_schwarz_', 306), ('mariosocrazy', 977), ('narcisonfor', 706), ('reacamcu', 23)]

# %%
def imprimir(lista2):
    print("Followers y sus nombres")
    for x in range(len(lista2)):
        print(lista2[x][0],lista2[x][1])

def pais_maspoblacion(lista2):
    pos=0
    for x in range(1,len(lista2)):
        if lista2[x][1]>lista2[pos][1]:
            pos=x
    print("Persona con mas followers:",lista2[pos][0])

# %%
imprimir(lista2)
pais_maspoblacion(lista2)
# Out:
# Followers y sus nombres
# Eresgamercom 589
# nico_marin2000 150
# Sebas_moratalla 138
# jpmrtinez 238
# JoseluHiguain 474
# reacamcu 23
# carloscharlie98 138
# InigualableSone 343
# Dolores87498568 109
# Elena25__ 316
# Diana44527 18
# Pilar261098 453
# lidia51995945 21
# deliaperezz_ 542
# elensj018 530
# Cosmeticosesse1 2
# Inmaalvareez_ 48
# Alex_Corral07 409
# claracxs 647
# atorrecilla_10_ 111
# luiscofern 45
# elenaafrndz 260
# RUGEMurcia 815
# angelaggarcia_ 259
# merimart 878
# olgaavn 143
# rotulcast 18
# Teresanava122 270
# aliiciiaa_15 120
# Ramonet37280098 4
# nurialcaina 350
# Enrique__Valero 753
# albertopereezzz 210
# Teresii10 140
# meerymoyaa 182
# lolaherranz 861
# jimmy_leann 5
# Ruben56677682 48
# Renataeljuri 68
# marinams__ 325
# joseelu16 83
# alba_marinn 216
# rokki 398
# danijorquera8 119
# toustusmuerto 472
# violetapintor 127
# Fran_Cano_ 662
# paulabenitezzz_ 8380
# Mefui1234567 439
# Luigi21Plus10 4
# Miriam47352133 3
# LaRa_1369 248
# marioazc0 78
# UCAM 37327
# Gravesen_1 104522
# legenwario 149
# 10Antoniorubio 196
# celdran_marina 71
# 23Mariajr 106
# SorteosGluup 66449
# EnPedagogas 1
# mathiasvera17 3311
# Carlos43523021 2
# diegomaper7 151
# sergiocayuela09 323
# Carras_10_ 213
# FuenVilches 278
# cristina_1401 262
# raquel_cayuela 294
# PinkPantera45 42
# AsturianoDani 69
# MyoLattAung1 39
# only4the_brave_ 19
# inforges 3107
# Paola54115195 21
# Noeliaq20 19
# guslpz5 127
# Leganes_CA 1118
# GameOfPhrases 156
# mobn14 214
# anaalvarezz78 4
# angelosilva1999 3
# Biri525v 295
# desconectaoff 7
# AgustinLopezL19 13
# Pepe01sa 470
# DesguaceParis 2132
# RAPDEL90 29
# barcelo_ramirez 2
# UCAMMurciaVAVEL 641
# raqueelorenzo20 299
# KitHaringtonism 491
# sergiooo_aa 212
# Marialopezlop26 115
# ManolitoCruck 8
# JuanAnt11393525 0
# Magia_De_Futbol 27146
# Josescamez72 22
# josescamez 33
# LENVAYrap 145
# PabloPyconety 15
# PLluste 4
# chupi_01 385
# chupi_9 52
# Loolaasnchzz 31
# pimi_perez95 12
# ApolloAgencia 12168
# Amrsale91785512 115
# makingmoney471 8
# Pepa05942772 2
# Carliu13 514
# AutosMerinoSL 158
# PatriciaRuizGo8 28
# lokakao1 137
# mariocabelloo 16
# carlos_vacas_10 18
# maariagimenezz 175
# FBPicksFree 2142
# Marioazc00 54
# sebascarrasco13 317
# gosi7madridista 198
# pablo_misi 14
# rodrigoespin9 276
# FBCjuvenil 51
# davidabril99 12
# luciapiconn 109
# MariaEspin9 363
# marttaxxii 212
# fjazorin88 137
# Desordensexual 21
# annaasola 539
# CristinaOlivaG2 6
# eleniita_1999 26
# Andreallorent06 10
# milagro20910048 9
# trulynoted 142
# porrilla20 128
# Cristin05240978 5
# creacionesmagi 776
# angiezr21 29
# runnawaywithhme 14
# paquita_morote 3
# PaquitaTorra 9
# TakeMe2WendysDO 2761
# carlitos_10v 25
# alberto54321611 2
# africagarciaaa 331
# 22_saritaa 9
# tufuturoesagua 58
# aroagm9 273
# diferente99 211
# 6c32ae10ac2a46b 12
# buenapsicologia 6616
# jesuscfernandez 55
# esp_patria 409
# Carmen_re16 39
# ncgcia 446
# Miguelaito99 188
# EDMagBlog 906
# tomasbarsa99 486
# diegoMA_99 223
# Djpedroalvarez 0
# ApuntasT 75
# wampaspain 106
# angelasnxz 288
# andresnv99 107
# mariaangel_7 72
# antoniodp160580 31
# AlquipirJuvenil 26
# alejandrogd836 128
# albertocanara 154
# cristiansurki28 36
# ASummerStory_Md 599
# jjbus99 696
# paularobles27 252
# albertosr10 127
# awiznerg84 114
# RH_19_11_99 24
# mariap_180202 708
# colladojocd1 144
# stonercum 381
# Ffhcvgh 72
# 15501pros 1781
# ijustfollow321 69
# Inspira79675042 478
# JuanJoseGuill14 4
# Javi_Carta1 765
# rosannalpz_ 562
# MarpePilar 5
# makysofii 16
# DJimenezzzz_ 210
# pa_sopar 21
# RANDALLANDERSO4 799
# CarmenSanchezDu 423
# 6_Pablo_9 1129
# claudia_10101 0
# crespicks 137
# iPaisajesEs 2100
# CaravacaEncuest 184
# ShishasDeModa 12194
# lauramorenilla_ 153
# marianiko_97 550
# serranotorres81 128
# FuturosCracksTV 9593
# alvaro16naranjo 608
# _inma123_ 72
# david05guerrero 405
# pobicanara 48
# bermejaito 151
# 991_mariajose 219
# Verdazos_es 614
# miryam_16700 40
# Mari22rojas 178
# javier_8_14 1
# mariah1139 303
# ArchivelFiestas 136
# oraval02 191
# lady_sandy94 207
# carmengarib99 119
# dominquefxp51 228
# DJ_Juanmi_WTF 290
# marina_celdran8 138
# mt22_maria 291
# belenamoor 628
# esmeral15254998 286
# pjnavarrete4 491
# alberto6cantero 105
# miguel_2732003 26
# Rrpplorca 388
# AnnaSanchzGea 601
# Sonialloret_11 122
# elennapolo 567
# rauliko7 304
# Dani_Ros10 52
# angelasnchlo 200
# mntsabril 474
# emiliete2001 34
# P_Retorno 277
# mariagonz_2000 272
# Aalex_241527 14
# WikiBorracheras 35
# belenmartinezl3 124
# RunningEnMurcia 226
# talianamayte22 46
# jeffpromotes 404
# LorenicaNavarro 664
# Spain_Under 4123
# yosoieljosete 2
# AnahiBR00 597
# mjgs_98 582
# _andreabernes 372
# ampaiesvega 69
# ErasJefferon 6
# NicolasMarin_10 506
# OrtegaRocio14 295
# Meroo112000 113
# VeraBianchi6 707
# Lucia10008 1059
# Leandro10_99 110
# JoseVic_Torres 319
# jabatocaravaca 158
# Isamodel99 552
# jonyxulo94 468
# Maria_gr04 372
# 43f360b58dcb47b 78
# rodrigoespin10 207
# PipaGozalbes 4816
# pCabEscandalo 306
# mariaferr1165 182
# AnimalSoundFica 38
# LaComparacion 110853
# MariaAbril_3 355
# carmen_9_ 154
# AllTheXperience 1881
# maria_nlpez 213
# CCEOdontolog 61
# NoroesteRioMula 1155
# ivanacorreas_9 329
# irenne99 269
# alejandro_MZGZ 25
# burguerciudadj 226
# enmabattu 872
# AnabelTudela 514
# edif7 191
# lauracorbalanS9 158
# albertocor12 79
# CaravacaFiesta 123
# MariCruzMontiel 297
# alexruizf10 377
# SergioCebolla5 85
# naicu123 145
# andrea_pr_10 659
# rocayu98 388
# nicugrecu38 22
# mayorking_3 288
# 2Andreu 643
# Mr_motivador 765
# grecu_nicu 30
# JJMotorSport 28
# aliciapozo21 340
# PaulaCaro20 269
# RuPeRR99 67
# mariacr286 497
# merasol3wixco 151
# carmenmaria_23 559
# lauralopezmart3 114
# Otra_Cosa0w0 0
# anakinty8 3
# esmeralda_ng23 110
# sergiocaamaque 491
# danifll03 313
# Lopez5Salva 722
# CaravacaCJ 143
# AAdri303 44
# ixiosmoixi 44677
# SonidoEDM 32956
# Marineeraa_ 838
# tlg94r 111
# Neassle 195
# AnamGazquez 498
# josephinenicol_ 187
# Jonathan_atlest 63
# mtcorreas7 501
# mariahonne 580
# marialopezlop08 187
# Paulaortuno 216
# maria_21piluka 522
# AliciaTorres_22 610
# elenaiborra23 465
# elenaortiz_99 393
# carmenmariia13 493
# MariinaFdez9 528
# 10TajMahal 83
# MaraAbril3 425
# MariaPuerta83 686
# magin_8 626
# PERIWES 228
# LuciaPicoon 620
# marrmrss 418
# josico_748 51
# Carmen_MariaMG 550
# Teresa_SM1 679
# mavisanchez22 196
# Maria22Rojas 434
# arqu_bizarra 135
# OsitoPerez 444
# Gines_Kopero 379
# miriam_robl 290
# GSJose8 375
# 14Ismaerobles 85
# MoyaRuizmoya 257
# HernaizAlba 1030
# antonioperezf97 50
# manucastipolo 168
# amnpz16 664
# jessica_megan12 48
# liguescaravaca 191
# Miriam_FL 536
# Elenamarin0 423
# Malmax5 366
# TipicoAquel 44
# cmlopezauguy 126
# alonso1528 41
# Paloma24_NV 931
# irenecaballos 582
# LauraReina99 732
# marinacj36 94
# dondrama46 30
# pgalvez12 263
# miripque 19
# Pikyjm 580
# mariiags17 284
# ErrGhetto 172
# Jaimesk8Romero 462
# IvanTorres_17 193
# MLPepito98 342
# carmenml_99 228
# samuelote1495 153
# Torrecilla52 459
# lourdes_tb99 595
# soniasszz 945
# PatriciaCeldran 403
# victoriamtnez13 294
# rubio_ruben 187
# Victoria_agudo 212
# picon_ap 260
# nataliamontanos 969
# rodriespin10 173
# ColladosAILD 1902
# Nuricastre 644
# leti1699 334
# anabel398 446
# Gines5Garcia 403
# Carmengaarciia 1063
# pedrohervas17 555
# mariagmay 321
# Mariia03_ 71
# ElenaMarin20 718
# Analove_13 261
# irenemt22 598
# mariags_17 75
# _tusonrisa01 1
# josemaarb 629
# AnabelTudelaL24 489
# sfglez_ 534
# lluviaponce138 231
# Laufg26 631
# ananavarro200 377
# rubiomt_ 841
# critian_perete 441
# Juliamarti98 457
# santos29mr 60
# LasDamas2014 94
# lasalcedo3 113
# clarasnxz 1000
# antonioabeiro_5 599
# Mariiaadelaamor 455
# Angelotta_28 486
# AnaGarcia1616 200
# mariasalinas98 493
# maginesko 152
# doriboluda 356
# cristianLop_80 39
# amparo_2610 498
# Angela_NV 438
# 8IsabelMaria8 794
# Alba9721 646
# MariaJoseLM9 593
# mariinatoral_98 712
# isabescavy 217
# MirandaIM25 534
# JesusGG_99 207
# LetiiSanchez98 389
# CarmenMJorquera 765
# pedrofm98 338
# Charly_797 552
# LuciaBoluda 789
# AnaMarinSanchez 534
# Carmencampos98 365
# Alberto_2209 474
# marta_romera 461
# elenaflive 441
# fer01786526 333
# elenaroca99 631
# Anaa_Capaarroos 526
# taamaraa_14 675
# Lauragp_99 710
# EstherLlamas2 663
# SrJuanPedro 162
# manuelolo66 168
# cristia23318358 120
# Deme10NBA 143
# FrasesChulas25 219
# mariaSF99 904
# Amantesdelamsic 207
# Martuchi7152 541
# chulesjesusc 251
# 27_LauraN 165
# Helen_rma 364
# pedrodavid_1996 400
# oscargonza96 121
# Raulgm0909 187
# sariita_smp 313
# JoseMarcos02 651
# davidmm99 94
# estefany_tuloca 267
# Nati_Munuera 456
# felipe_916 657
# chemari_4 488
# alesceldran 96
# MariaCorrales16 493
# inthemadnesss 3146
# isabelsanxez 338
# Rubia_65 117
# aaroncelb 590
# andreabril1999 680
# alvaroalarte 200
# AndreaRomerico 133
# eliagr59 632
# adriaN_Rdez26 154
# juanto_15 456
# pilarrvillo 293
# VaroFcb 698
# troyano349 528
# Rosiitadeltoro 750
# MariaPeVillo 479
# pablof50 487
# Alberto_Rubio9 229
# EmilioMsjs_5 870
# pedricola2000 48
# Sandra_GG18 236
# juanma9_9 425
# andreaRomS 68
# adrigd_69 5
# diimassanchez 572
# alicialopezmuoz 564
# elenaAV_99 240
# PalomaRigabert 539
# andrea_lude 529
# mariaa_naavarro 126
# caparrs_ana 75
# mariasalcedo_8 103
# alvatrios 347
# Rajao_5 701
# JulianR5 282
# MoroteAlba 507
# antoniosola98 309
# albamartinezz_9 321
# danielazorin7 781
# _luiscamacho75 481
# Patrigarciamel 504
# AlejandroDinten 850
# andrearomel10 590
# Ivanfeg1998 435
# JoseSanchez2559 419
# adrilzlz 443
# Sergioelespanol 510
# marinarbortz_ 662
# andrea_PG08 956
# ChechuMrtnz98 471
# dani13sanchez 96
# Torralba6 270
# zaplana8 148
# Pedro_J_MG 263
# adri_gd69 676
# AnaRigabert_ 250
# bataneroantonio 413
# ValySanchez97 740
# jesuspepi15 260
# Torralba96 430
# emiliojose_9 284
# juananMARIN3 422
# GL_Josema 290
# joseaportero1 332
# cristianperete 186
# PedroAlarcon25 839
# carliticos99 460
# TeresadeFreesaa 335
# Derti14 686
# AdriSanchezC5 185
# A_DavidFdez10 532
# rubensanchezlop 410
# 13_sweet13 404
# jose5sanchez 517
# rafa_pucelaa 592
# Futbol_Actual_ 105
# mariatj97 543
# Patrii990 628
# YaryDavid 276
# manolog64752622 445
# Mayorking10 747
# xiki_11 396
# MrosagmC 119
# AngelGM9 752
# loles_99 434
# Alberto_2606 254
# albasanchez990 672
# mariiagb14 402
# andreagl_99 532
# ana_gimenez_99 379
# MrCarlosAndres 708
# anamariapuerta_ 307
# JuanAnt_Fem 268
# 99Morote 241
# PiedadGuillen99 270
# TariqMay 0
# Alber_MaBer 437
# LMariadelao 556
# alberto_gomez88 559
# Mromar5432 143
# MiguiGameplays 290
# Persona con mas followers: LaComparacion

# %%
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")

        listaordenada = []
        listaordenada.append(ith_tweet[6])
        

        
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)

# %%
print("Enter Twitter HashTag to search for")
words = input()
print("Enter Date since The Tweets are required in yyyy-mm--dd")
date_since = input()
 
# number of tweets you want to extract in one run
numtweet = 100
scrape(words, date_since, numtweet)

print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# Valencia
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2022-01-08
#
# Tweet 1:
# Username:254rapper
# & @tranworldradio
# ,designer, artiste,mentor, motivator,future worldwide C.E.O @richfamilyent
# Location:nairobi, kibera kenya
# Following Count:336
# Follower Count:371
# Total Tweets:13879
# Retweet Count:1
# Tweet Text:During the sixth kilometre Simiu began to take a turn at the helm, and with some 20 minutes on the clock the 26-year-old Kenyan opened a gap on Gudeta, which grew over the following kilometres. https://t.co/KKZWLAb0Yv
# Hashtags Used:[]
#
# Tweet 2:
# Username:RafoZd
# Description:
# Location:
# Following Count:128
# Follower Count:0
# Total Tweets:15
# Retweet Count:0
# Tweet Text:@MadridXtra Beating Valencia in Supercopa with 2 reds. Great memories.
# #halamadrid
# Hashtags Used:['halamadrid']
#
# Tweet 3:
# Username:AdriSuchoBlaink
# Description:A. Blázquez Riola 2021
#  - Paleontólogo, Geólogo y Paleoartista ⛏️🦕🦖
# - ACEPTO ENCARGOS!💬
# Madrid, España #PaleoArtist
# Location:San Sebastián de los Reyes, Es
# Following Count:1008
# Follower Count:1047
# Total Tweets:24896
# Retweet Count:2
# Tweet Text:🦕New paper on Late Jurassic ornithischians of Spain by Sánchez-Fenollosa et al. (2021) "Tracing Late #Jurassic ornithopod diversity in the eastern Iberian Peninsula: Camptosaurus‑like postcranial remains from #Alpuente (#Valencia, #Spain)" #Paleontology
# https://t.co/BxAmquWyc6 https://t.co/pm6fogXqv0
# Hashtags Used:['Jurassic']
#
# Tweet 4:
# Username:MiddIeWinger
# Description:a lot of my tweets are not serious 👍
#
# vinicius jr.
# Location:Nabeu Berest
# Following Count:641
# Follower Count:398
# Total Tweets:18020
# Retweet Count:20
# Tweet Text:Vinicius Jr vs Valencia (H)
# Man of the match 🏅
#
# (@vinijr) https://t.co/Tz5ithRxHW
# Hashtags Used:[]
#
# Tweet 5:
# Username:MuwanguziEdwin
# Description:CEO EJ Jersey store Am a ,careful ,humble,extravagant person .GGMU ,Hala Madrid, Ronaldo 🐐 Laflame addict Trav all the way
# Location:
# Following Count:1463
# Follower Count:906
# Total Tweets:18748
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 6:
# Username:the_colvin
# Description:I don’t believe I’m better than anybody but nobody is better than me. antropólogo. ECU Grad Student
# Location:Greenville, NC
# Following Count:3651
# Follower Count:741
# Total Tweets:56192
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 7:
# Username:ReviloLDN_
# Description:#CFC 🇳🇬🇯🇲 | Football & bants. #BLM ✊🏾
# Location:South London
# Following Count:951
# Follower Count:1384
# Total Tweets:164690
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 8:
# Username:elprincetee
# Description:Instagram : @elprincetee
# Location:Lagos, Nigeria
# Following Count:4938
# Follower Count:4056
# Total Tweets:312204
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 9:
# Username:Richie1S
# Description:🕋 الحمد لله🌏❤️NP
# Location:
# Following Count:988
# Follower Count:1761
# Total Tweets:106281
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 10:
# Username:OlowoSamod
# Description:if you don't wanna expire be with an empire...@FCbarcelona
# Location:
# Following Count:744
# Follower Count:315
# Total Tweets:24424
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 11:
# Username:carIosrma
# Description:@realmadrid
# Location:Madrid
# Following Count:178
# Follower Count:803
# Total Tweets:334
# Retweet Count:0
# Tweet Text:@onlyfarouk12 They’ve got Valencia away and Celta Vigo next, not easy tbh
# Hashtags Used:[]
#
# Tweet 12:
# Username:onabanjo_G
# Description:
# Location:
# Following Count:1929
# Follower Count:1243
# Total Tweets:76131
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 13:
# Username:JaySepako1
# Description:Fashion, Entertainment and Praise&Worship
# Location:Botswana
# Following Count:1659
# Follower Count:577
# Total Tweets:32965
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 14:
# Username:TheOpemz
# Description:I'm not your regular | Charismatic personality | Chelsea FC supporter | Son of the MOST HIGH | Ardent believer in a better Nigeria and a united Africa
# Location:Where my heart is
# Following Count:11050
# Follower Count:10099
# Total Tweets:74659
# Retweet Count:14
# Tweet Text:Wallahi that Valencia's tweet is the craziest thing I've seen an official account tweet🤣🤣🤣😭😭😭
# Hashtags Used:[]
#
# Tweet 15:
# Username:valencia_utd
# Description:
# Location:Middleburg
# Following Count:333
# Follower Count:378
# Total Tweets:5873
# Retweet Count:14275
# Tweet Text:i owe this year to myself.
# Hashtags Used:[]
#
# Tweet 16:
# Username:GeorgeChika9
# Description:vamozzzzzzzz Messi@10
# Location:jubril martins surulele Lagos
# Following Count:587
# Follower Count:176
# Total Tweets:13947
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 17:
# Username:RohitSa57677571
# Description:
# Location:
# Following Count:54
# Follower Count:20
# Total Tweets:4908
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 18:
# Username:Andz_i_am
# Description:• ♓︎ • A Lone Sunflower 🌻 Energy Vampire 🧛‍♀️ High Vibrational Being 🧚🏾‍♀️ Don’t Hate - Meditate 🧘🏾‍♀️
# Location:Sub-Saharan Africa
# Following Count:777
# Follower Count:2774
# Total Tweets:243152
# Retweet Count:3
# Tweet Text:📸 Was a privilege to shoot this athlete when he ran in Sa last year. A diamond in the rough, runs 26:57 over 10km on the road today in Valencia. 6th fastest time ever https://t.co/OXVyGFnU6l
# Hashtags Used:[]
#
# Tweet 19:
# Username:BrucePaanii
# Description:
# Location:
# Following Count:4971
# Follower Count:783
# Total Tweets:11955
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 20:
# Username:theMissingPete
# Description:ชื่อ พีท / เสพติดความเหงา / not a morning person / introvert / #รักในหลวง / ความสามารถพิเศษ : รักเดียวใจเดียว / #TeamIronMan / #Excelsior / ENFJ-T
# Location:Earth
# Following Count:2281
# Follower Count:1543
# Total Tweets:260373
# Retweet Count:1
# Tweet Text:After Valencia's official account tweeted their anger over Madrid's penalty award, Pique couldn't help getting involved and having a dig as well.
#
# He's becoming quite the sensation on Twitter after showing his bank statements the other day, now this. 😂
#
# https://t.co/LtnkJVSq5B
# Hashtags Used:[]
#
# Tweet 21:
# Username:FranklinUdeh3
# Description:FC BARCELONA FAN💣 PROUDLY NG🇳🇬
# Location:
# Following Count:977
# Follower Count:446
# Total Tweets:63287
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 22:
# Username:cookieboyfriend
# Description:ishola❤️@chelseafc 💙💙💙 August 19😉🇳🇬🇳🇬🇳🇬Christianity!!! unattractive😇😇Davido❤️💯. TRANQUIL⭕️🤲🏾 Accountant👨‍🎓💯
# Location:Ibadan, Nigeria
# Following Count:1401
# Follower Count:543
# Total Tweets:40752
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 23:
# Username:lexphul
# Description:The W0rLd IS YOuRs bUT FEAR GOD @ChelseaFc
# Location:Accra, Ghana
# Following Count:583
# Follower Count:496
# Total Tweets:3137
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 24:
# Username:NimiRengga_W
# Description:
# Location:Old Trafford
# Following Count:388
# Follower Count:390
# Total Tweets:108361
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 25:
# Username:LuisCollantesR
# Description:PhD Student in Geology (UC🇵🇹). MSc in Applied Paleontology (UV/UA). Geologist (UHU🇪🇸). Cambrian trilobites and other faunas.
# Location:Huelva, Andalucía
# Following Count:714
# Follower Count:1458
# Total Tweets:15598
# Retweet Count:2
# Tweet Text:🦕New paper on Late Jurassic ornithischians of Spain by Sánchez-Fenollosa et al. (2021) "Tracing Late #Jurassic ornithopod diversity in the eastern Iberian Peninsula: Camptosaurus‑like postcranial remains from #Alpuente (#Valencia, #Spain)" #Paleontology
# https://t.co/BxAmquWyc6 https://t.co/pm6fogXqv0
# Hashtags Used:['Jurassic']
#
# Tweet 26:
# Username:Yaqub__M
# Description:✊🏾
# Location:
# Following Count:770
# Follower Count:534
# Total Tweets:227088
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 27:
# Username:safiuddinudden_
# Description:Pujaan hati Lalisa Manoban #LISA𓃠  & #LALISA #LISA #리사
# Pencinta kartun penjajah 1945 &
# Peminat kelab bola sepak terkuat dunia.
# Location:Hati Lisa
# Following Count:850
# Follower Count:1570
# Total Tweets:80232
# Retweet Count:86
# Tweet Text:Fun fact: Valencia (6) and FC Barcelona (5) are the teams to have most penalties awarded this season in La Liga.
#
# Guess whose mouth was loudest after Madrid got their RIGHT call tonight?
#
# Team on 6th &amp; respectively 9th with 17 &amp; 21 pts behind Los Blancos.
# Hashtags Used:[]
#
# Tweet 28:
# Username:samipyosi
# Description:🤴🤴
# Location:
# Following Count:2145
# Follower Count:854
# Total Tweets:70308
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 29:
# Username:TheLosVikingos
# Description:No such thing as a life that's better than yours.
# Mechanical Engineer | Football enthusiast
# If I forget to fb, DM.
# Location:
# Following Count:166
# Follower Count:80
# Total Tweets:7433
# Retweet Count:0
# Tweet Text:@ESPNFC Even Valencia fan base is ashamed of the club. Bought by a businessman, that's why they have turned off the replies section. Shame.
# Hashtags Used:[]
#
# Tweet 30:
# Username:Fosterperry10
# Description:
# Location:
# Following Count:393
# Follower Count:78
# Total Tweets:11879
# Retweet Count:22
# Tweet Text:Did the Valencia account tweet about how Vini made them cry more yet?
# Hashtags Used:[]
#
# Tweet 31:
# Username:nursenette69
# Description:Poly pan proud! Queer mom and Bay Area union nurse. Trans Rights are Human Rights! Stay safe, mask up! Solidarity!  Fully Vaxxed - even booster!
# Location:California
# Following Count:4989
# Follower Count:612
# Total Tweets:33138
# Retweet Count:7
# Tweet Text:a new massive luxury condo building at 198 Valencia only has 4 BMRs and they are all 100% AMI (which means you must make 95K a year to live there).
#
# Is this what you think San Francisco can afford @MattHaneySF and @HillaryRonen ??? https://t.co/031RNW3jDV
# Hashtags Used:[]
#
# Tweet 32:
# Username:cmarti27_LVES
# Description:
# Location:
# Following Count:88
# Follower Count:59
# Total Tweets:146
# Retweet Count:11
# Tweet Text:El Dorado has qualified 3 students to the TMEA Texas All State Band!!!
#
# Jacob Arias - Saxophone
# Jacob Valencia - Clarinet
# Micah Carrasco - Tuba
#
# #Reignite #sisdfinearts
# #TeamSISD #OneEmpire
# @SISD_FineArts
# @EDAztecs_HS
# Hashtags Used:[]
#
# Tweet 33:
# Username:Fosterperry10
# Description:
# Location:
# Following Count:393
# Follower Count:78
# Total Tweets:11879
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 34:
# Username:MiskaP97
# Description:Metalhead & Hockey Freak 😜
# Location:Helsinki
# Following Count:1137
# Follower Count:399
# Total Tweets:550327
# Retweet Count:51
# Tweet Text:2⃣ Back for part ✌️!
# ▶️ @realmadriden 1-0 @valenciacf_en
# 💻 https://t.co/7a8FNICv2F
# #RealMadridValencia https://t.co/U5Tbwli12a
# Hashtags Used:['RealMadridValencia']
#
# Tweet 35:
# Username:Phil9226
# Description:Be happy for this moment. This moment is your life! - Omar Khayyam           #God #RealityTV #Sports #Music #PositiveVibes #InARelationship
# Location:Jamaica & Rockford, IL
# Following Count:497
# Follower Count:178
# Total Tweets:35024
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 36:
# Username:malukaguguletho
# Description:Sport Football News Radio & TV but most of all gunner. My tweets r my thoughts not the people I follow or the company I work 4
# Location:South Africa
# Following Count:2002
# Follower Count:494
# Total Tweets:11996
# Retweet Count:0
# Tweet Text:@MasekoValencia U always looking gorgeous valencia
# Hashtags Used:[]
#
# Tweet 37:
# Username:BalogunKorede8
# Description:youcanneverplan#God’splan#
# Location:
# Following Count:346
# Follower Count:164
# Total Tweets:7113
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 38:
# Username:garbadaru
# Description:GOD FIRST!!!
# Location:Egypt
# Following Count:1523
# Follower Count:1423
# Total Tweets:283890
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 39:
# Username:Benihunnids
# Description:⬇️ pizzas Free Shawn
# Location:Atlanta, GA
# Following Count:601
# Follower Count:699
# Total Tweets:42762
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 40:
# Username:Westernboi21
# Description:#Team FCB
# Location:ALL OVER DWORLD🌍
# Following Count:3621
# Follower Count:3925
# Total Tweets:57454
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 41:
# Username:sportbible
# Description:The Official SPORTbible. A Way Of Life.
# Location:contact@sportbible.com
# Following Count:3066
# Follower Count:1518102
# Total Tweets:72408
# Retweet Count:1
# Tweet Text:After Valencia's official account tweeted their anger over Madrid's penalty award, Pique couldn't help getting involved and having a dig as well.
#
# He's becoming quite the sensation on Twitter after showing his bank statements the other day, now this. 😂
#
# https://t.co/LtnkJVSq5B
# Hashtags Used:[]
#
# Tweet 42:
# Username:MauroErbiti
# Description:(29) De Avellaneda. Rey de Copas. Premier League y NBA. Cinéfilo y seriéfilo. Homo Ludens. Symphathy for the Devil. Strive for greatness. IG: erbitimauro
# Location:Argentina
# Following Count:3
# Follower Count:475
# Total Tweets:319096
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 43:
# Username:Albert_August
# Description:Create Don't Follow⚜️🇹🇿| @manutd #ILoveThisGame
# Location:Kuching, Sarawak
# Following Count:715
# Follower Count:264
# Total Tweets:5651
# Retweet Count:0
# Tweet Text:AWB reminds me that Antonio Valencia was an important player for United 😖😖
# Hashtags Used:[]
#
# Tweet 44:
# Username:lemuel_risaac
# Description:Male instagram lemuel_reuel_isaac Facebook lemuel reuel isaac
# Location:Kampala
# Following Count:1664
# Follower Count:742
# Total Tweets:217161
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 45:
# Username:ruddyonline
# Description:Where I'm from pain kills man like Jiraiya
# Location:
# Following Count:1606
# Follower Count:361
# Total Tweets:14680
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 46:
# Username:zerix52479783
# Description:
# Location:
# Following Count:2
# Follower Count:7
# Total Tweets:1755
# Retweet Count:3
# Tweet Text:⚽ #LaLiga - in 15 min ⚽
#
# BET NOW ➡️ https://t.co/dOfXfKWwRR
#
# 1️⃣ Granada CF - FC Barcelona
# 2️⃣ Real Madrid- Valencia CF
#
# Play in Parlay and win more 🤩💰
# ️
# #Soccer #Bitsler @Bitsler_Indo @Bitsler_Brasil #football @LaLiga #Laliga @realmadrid @FCBarcelona @GranadaCF @valenciacf https://t.co/L1EnRgVZot
# Hashtags Used:['LaLiga']
#
# Tweet 47:
# Username:MemphisForster
# Description:Lions don't compare themselves to humans...
# Meister CEO 💵
#    M    E   I   S  T  E  R.  👙
#
# arnoldlubinga4@gmail.com
# +256752274229 😏
# Location:Kabalagala,Uganda
# Following Count:645
# Follower Count:764
# Total Tweets:3762
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 48:
# Username:its_abbajnr
# Description:Geologist 🏔⚒| Aquarius ♒️| Cat person 🐈| Introvert | Movie buff 🎥| Music addict🎵| Tourist and a Madridista ⚪️.
# Location:Everywhere
# Following Count:930
# Follower Count:392
# Total Tweets:16988
# Retweet Count:73
# Tweet Text:Really don’t think this kind of thing is a good look, even if a club feels hard done by, and it’s increasingly common.
#
# Also: Valencia were presumably fine with the three penalties they were awarded in their own 4-1 win over Real Madrid last season… https://t.co/ZLCLwVXkhf
# Hashtags Used:[]
#
# Tweet 49:
# Username:Valencia_PVM
# Description:
# Location:
# Following Count:3653
# Follower Count:3255
# Total Tweets:1173
# Retweet Count:6406
# Tweet Text:me as a lawyer: but your honor 🥺🥺🥺 🥺🥺🥺 🥺🥺🥺🥺 🥺🥺🥺🥺 🥺🥺🥺🥺🥺🥺🥺🥺🥺 🥺🥺🥺🥺🥺🥺🥺🥺 🥺🥺🥺🥺🥺🥺🥺 🥺🥺🥺🥺🥺🥺 🥺🥺🥺🥺🥺 🥺🥺🥺🥺 🥺
# Hashtags Used:[]
#
# Tweet 50:
# Username:auwal__mbt
# Description:My mother my paradise👩‍👦|| 01:12🎊🥳 || Striving for jannah✨|| After all patience, beautiful things await🌝
# Location:katsina
# Following Count:1489
# Follower Count:6043
# Total Tweets:13691
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 51:
# Username:nuevothomas
# Description:brb🚶🏾‍♂️
# Location:LDN/🇯🇲
# Following Count:202
# Follower Count:66
# Total Tweets:391
# Retweet Count:12
# Tweet Text:Luka Modrić vs Valencia CF, the numbers🧮
#
# In 70 minutes:
# 63 touches
# 91% pass accuracy
# 3 chances created
# 2/4 accurate long passes
# 1/1 successful dribbles
# 3/4 ground duels won
# 2 fouls won
# 1 interception
#
# A solid performance, unlucky again to not score✨ https://t.co/a3k14bMAU6
# Hashtags Used:[]
#
# Tweet 52:
# Username:fabriziofan_001
# Description:FOOTBALL/Politics
# Location:
# Following Count:209
# Follower Count:61
# Total Tweets:4074
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 53:
# Username:Haywh9_official
# Description:|FC Barcelona fan❤️💙|| I hate Real Madrid.
# Location:Somewhere
# Following Count:115
# Follower Count:61
# Total Tweets:1041
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 54:
# Username:kaylinhairston
# Description:life is good :)
# Location:
# Following Count:205
# Follower Count:158
# Total Tweets:850
# Retweet Count:28649
# Tweet Text:I remember when Instagram was straight pictures. No DMs, no archives, no replying to comments, no stories, no calls, no live, no videos, just the Valencia filter and vibes.
# Hashtags Used:[]
#
# Tweet 55:
# Username:TitusFortune
# Description:•childofGod 😇❤ •petroleumengineer ⛽️•riversgirl💯 •90’sbabygirl👶🏻 🍼 •scorpio ♏️🤑 •fitnesslover💕🏋🏽‍♀️🏋🏽‍♀️ •chelseafan 🦋💙•tipster 👸🏽🏀🎾🏒⚽️🔌
# Location:Boom, Queen
# Following Count:457
# Follower Count:6886
# Total Tweets:43018
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 56:
# Username:pu_cule10
# Description:Messi Prop 🐐👑
#
#
# GFX Designer | Messi | Barcelona
#
# Use to be Fifa_Viper 🙃
# Location:
# Following Count:1021
# Follower Count:1301
# Total Tweets:28665
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 57:
# Username:TheHasKarim
# Description:Social X graphics: @bbcsport @bbcmotd @squawka @ItaFootPod @LaLigaLowdown @_RMmedia | writer @therealchampsfs
#
# DMs open for work enquiries. Views my own.
# Location:Birmingham, England
# Following Count:1460
# Follower Count:4571
# Total Tweets:24945
# Retweet Count:0
# Tweet Text:Casemiro was solid against Valencia. Why would you bench him? And who plays instead? https://t.co/UEqFSNGiyj
# Hashtags Used:[]
#
# Tweet 58:
# Username:rslashgunners
# Description:Official twitter account for the foremost online Arsenal supporters group.
# Location:London, England
# Following Count:104
# Follower Count:1488
# Total Tweets:46932
# Retweet Count:0
# Tweet Text:The 2nd leg UEL semi away vs Valencia almost three years ago, is still one of THE best performances I've seen this club do over the last 10 years https://t.co/hJXivbKtnB
# Hashtags Used:[]
#
# Tweet 59:
# Username:MrObidiaso
# Description:Physiotherapist, waiting to bui.:
# Location:
# Following Count:79
# Follower Count:13
# Total Tweets:383
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 60:
# Username:vantos_com
# Description:GUNNERFORLIFE
# Location:Port Elizabeth, South Africa
# Following Count:1190
# Follower Count:384
# Total Tweets:30575
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 61:
# Username:hamzashah12512
# Description:Football Lover. ⚽⚽⚽
# Location:Rawalpindi, Pakistan
# Following Count:467
# Follower Count:89
# Total Tweets:38366
# Retweet Count:118
# Tweet Text:The only thing Valencia got robbed of tonight was their souls being snatched by Vinicius. Blessed for all the people involved in that transfer and his development.
# Hashtags Used:[]
#
# Tweet 62:
# Username:HuqmanK
# Description:KrMan
# Location:
# Following Count:637
# Follower Count:141
# Total Tweets:4537
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 63:
# Username:hawi_theeVersal
# Description:Liverpool Fc ❤️⚽️ I see it 👀. I want it👈🏾. I dream it 👼. I work hard ✊🏿. I grind til I own it 💯. Hustle + Faith = Success. You know nothin bout me 👌
# Location:Depressed But Happy
# Following Count:1692
# Follower Count:1874
# Total Tweets:22844
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 64:
# Username:_Mazeuw
# Description:Peace Out ✌. https://t.co/1rO1VaqZ3M
# Location:
# Following Count:305
# Follower Count:1050
# Total Tweets:392275
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 65:
# Username:Dehuva
# Description:
# Location:Buenos Aires - Lima
# Following Count:2338
# Follower Count:453
# Total Tweets:54308
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 66:
# Username:likwidzman
# Description:my looks
# Location:Accra, Ghana
# Following Count:695
# Follower Count:650
# Total Tweets:15179
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 67:
# Username:jp_clinton
# Description:To be absent from this body and to be present with the Lord, is what I desire and that is why I run the race.
# John 3:16 | Romans 10:9
# Location:
# Following Count:2137
# Follower Count:101
# Total Tweets:18342
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 68:
# Username:RED7OO
# Description:random brown dude be everywhere 🦖🦈🐾🤡👹🎩🔥🤖🎃🚶🏽‍♂️🎶🎸🥁🎪🎠 Imaginémonos Cosas Chingonas 🇲🇽. MIA SAN MIA 🔴⚪️
# Location:DOGHOUSE
# Following Count:863
# Follower Count:2268
# Total Tweets:78758
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 69:
# Username:Alexand24467960
# Description:Ex Árbitro de la FVF EX comisario de la FVF deporte 100% conversación  amena
# Location:
# Following Count:580
# Follower Count:26
# Total Tweets:1412
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 70:
# Username:oozyswonzy
# Description:One of the best lessons you can learn in life is to master how to remain calm.
# Location:Airport Residential Area
# Following Count:1122
# Follower Count:150
# Total Tweets:20377
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 71:
# Username:PD_Mocho
# Description:Vertebrate Paleontologist in Instituto Dom Luiz, Universidade de Lisboa @idlLuiz. #LGBTQIA. Associate Researcher of @UNED and @NHMLA and member of @ALTSHN
# Location:Lisboa, Portugal
# Following Count:970
# Follower Count:1504
# Total Tweets:10147
# Retweet Count:2
# Tweet Text:🦕New paper on Late Jurassic ornithischians of Spain by Sánchez-Fenollosa et al. (2021) "Tracing Late #Jurassic ornithopod diversity in the eastern Iberian Peninsula: Camptosaurus‑like postcranial remains from #Alpuente (#Valencia, #Spain)" #Paleontology
# https://t.co/BxAmquWyc6 https://t.co/pm6fogXqv0
# Hashtags Used:['Jurassic', 'Alpuente', 'Valencia', 'Spain', 'Paleontology']
#
# Tweet 72:
# Username:kutineric
# Description:whatever our minds are calling, no form of knowledge is antagonistic to it.
# Location:Atasomanso
# Following Count:817
# Follower Count:292
# Total Tweets:15755
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 73:
# Username:GunnersReddit
# Description:I check the rising posts on /r/Gunners and post them here every 10 or so minutes.  Please note that I am just a bot so I won't reply.
# Location:Holloway
# Following Count:26
# Follower Count:1188
# Total Tweets:159620
# Retweet Count:0
# Tweet Text:The 2nd leg UEL semi away vs Valencia almost three years ago, is still one of THE best performances I've seen thi... https://t.co/Eg3eN5pLI5
# Hashtags Used:[]
#
# Tweet 74:
# Username:Perfectevans5
# Description:Here.
# Location:Somewhere on Earth
# Following Count:1555
# Follower Count:1894
# Total Tweets:18923
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 75:
# Username:hariansyahakbar
# Description:kenapatuu
# Location:
# Following Count:253
# Follower Count:72
# Total Tweets:2864
# Retweet Count:86
# Tweet Text:Fun fact: Valencia (6) and FC Barcelona (5) are the teams to have most penalties awarded this season in La Liga.
#
# Guess whose mouth was loudest after Madrid got their RIGHT call tonight?
#
# Team on 6th &amp; respectively 9th with 17 &amp; 21 pts behind Los Blancos.
# Hashtags Used:[]
#
# Tweet 76:
# Username:Azk13king
# Description:Founder de @AZKitsePES - Creador de Contenido de #PES, #eFootball, #FIFA22, #UFL; El mejor lugar para obtener información, Option File, Gamplays, Consejos y Más
# Location:Túrin
# Following Count:346
# Follower Count:329
# Total Tweets:3951
# Retweet Count:8
# Tweet Text:VALENCIA @valenciacf
# Concept Kit PES 2021
# Inspired by the 97-98 kit
# Made by: @trick8s
# DOWNLOAD: https://t.co/9SYfWY6i6b
#
# #eFootballPES2021 #kitmaker #conceptKit #kit
# #puma #design #football #ValenciaCF #LaLiga #Valencia  #VCF #PES https://t.co/XYsqHyoizD
# Hashtags Used:[]
#
# Tweet 77:
# Username:Tpmyaka
# Description:
# Location:Gingindlovu, South Africa
# Following Count:4998
# Follower Count:1156
# Total Tweets:55600
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 78:
# Username:PaulWadePT
# Description:Marathon Running Paramedic, Advanced Clinical Practitioner father of twins
# Location:Radcliffe on Trent, England
# Following Count:1582
# Follower Count:426
# Total Tweets:8420
# Retweet Count:8
# Tweet Text:Valencia 10k official times:
#
# Emile Cairess 27:44 - equal second in UK AT list.
# Jonny Mellor 28:32 PB
# Adam Clarke 28:36 PB
# Phil Sesemann 28:58
#
# Beth Kidger 32:53 PB
# Steph Davis 32:58 PB
# Hashtags Used:[]
#
# Tweet 79:
# Username:FrancisRwahire
# Description:Engineer.
# @ChelseaFC
# @Warriors
# @49ers
# Location:Kampala, Uganda
# Following Count:1302
# Follower Count:2229
# Total Tweets:7531
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 80:
# Username:Alextavarezzz
# Description:help
# Location:São João da Madeira, Portugal
# Following Count:1133
# Follower Count:246
# Total Tweets:77677
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 81:
# Username:elijah_baah
# Description:🇬🇭🇫🇷 IM.POSSIBLE. Can't tell where the journey will end but I know where to start #Sowakemeupwhenitsallover @fcbarcelona ❤️💙 #Messi
# Location:
# Following Count:14888
# Follower Count:15251
# Total Tweets:6615
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 82:
# Username:aminudazis
# Description:ꦤꦺꦏ꧀​ꦏꦺꦴꦮꦺ​ꦠꦏꦺꦴꦤ꧀​ꦲꦺꦴꦥꦺꦴ​ꦲꦂꦠꦶꦤꦺ​ꦪꦺꦴ​ꦲꦏꦸ​ꦩ꧀ꦧꦫꦁ​​ꦲꦺꦴꦫ​ꦫꦺꦠꦶ | Hala Madrid y Nada Mas!!
# Location:Planet Earth
# Following Count:122
# Follower Count:3533
# Total Tweets:36100
# Retweet Count:13
# Tweet Text:Marca on Valencia’s Twitter account claiming Real Madrid robbed the match with yesterday’s penalty and which Pique also commented on (dude your team is 6th in the league focus on that😮‍💨😭): “Real Madrid got only 3 penalties in the last 13 months of league action.” https://t.co/YUpbd0pQme
# Hashtags Used:[]
#
# Tweet 83:
# Username:PeterEs35190855
# Description:
# Location:Sekondi Takoradi, Ghana
# Following Count:5002
# Follower Count:2387
# Total Tweets:6246
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 84:
# Username:KM_Khanye
# Description:Coach. Educator. Lunatic. Passionate. Pedagogue. Football lover. Virgo. in Love with MSFC.👆🏿
# mtunzikhanye@gmail.com.
# Location:Nigel, South Africa
# Following Count:4757
# Follower Count:4759
# Total Tweets:48979
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 85:
# Username:valencia_utd
# Description:
# Location:Middleburg
# Following Count:333
# Follower Count:378
# Total Tweets:5873
# Retweet Count:460
# Tweet Text:@akyaa_yeboah Twitter keeps fueling my insecurities
# Hashtags Used:[]
#
# Tweet 86:
# Username:barcaarounds
# Description:@barcaaround from Instagram. I Post Random Stuffs Here. 😉
# Location:
# Following Count:504
# Follower Count:126
# Total Tweets:26234
# Retweet Count:47
# Tweet Text:🚨 YOU CAN WIN A TRIP TO VALENCIA VS. BARCELONA IN FEBRUARY 🚨
#
# Take part in @LaLiga's Ultimate Challenge:
#
# - Predict the winner AND final score of tomorrow's Sevilla vs. Atlético Madrid match
# - Use #LaLigaUltimateChallenge and #ESPNcontest
#
# RULES: https://t.co/A9kGarA1G0 https://t.co/8zkFdUqh7A
# Hashtags Used:[]
#
# Tweet 87:
# Username:david_oheha
# Description:Can i be your friend?
# football and others.
# Culer ❤️💙
# Location:Abuja, Nigeria
# Following Count:1843
# Follower Count:1843
# Total Tweets:12626
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 88:
# Username:Staceydee12181
# Description:Your NBF boo, always simping for science. Loved like a sumbitch 💖
#
# (NBF = nerdy but flirty 🤓)
# Location:
# Following Count:621
# Follower Count:416
# Total Tweets:5507
# Retweet Count:0
# Tweet Text:@HonestLeYo 405 from Carson to Valencia, on a Saturday,  like a dumbass.
#
# Cali folks will understand. 😊
# Hashtags Used:[]
#
# Tweet 89:
# Username:zeroEnajy
# Description:i'm not a robot #teamMessi🐐 #RespectCR7 🐐 Drake🐐
# Location:I bitter
# Following Count:948
# Follower Count:687
# Total Tweets:94444
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 90:
# Username:SLANGZTA_
# Description:Backup @Slangzta
# Location:
# Following Count:662
# Follower Count:71
# Total Tweets:95601
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 91:
# Username:AlexButusenga
# Description:| 💰🤑Marketer | Lover of sunflowers 🌻 | Butternut enthusiast | I’m not here to stroke your ego | Fashion is my second favorite F-word💍👠💃 #PeoplePower #NUP✊
# Location:Uganda
# Following Count:1371
# Follower Count:767
# Total Tweets:17533
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 92:
# Username:Ibraimovic04two
# Description:#justaniconliving✌️
# Location:
# Following Count:384
# Follower Count:484
# Total Tweets:22713
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 93:
# Username:marathontalk
# Description:A free running podcast presented by @myelling and @rushbynature Out every other Wednesday.
# Location:England
# Following Count:893
# Follower Count:28231
# Total Tweets:18229
# Retweet Count:8
# Tweet Text:Valencia 10k official times:
#
# Emile Cairess 27:44 - equal second in UK AT list.
# Jonny Mellor 28:32 PB
# Adam Clarke 28:36 PB
# Phil Sesemann 28:58
#
# Beth Kidger 32:53 PB
# Steph Davis 32:58 PB
# Hashtags Used:[]
#
# Tweet 94:
# Username:sudais4pf
# Description:only the family. 4our pockets full.
# Location:CRENSHAW SLAUSON
# Following Count:436
# Follower Count:442
# Total Tweets:27493
# Retweet Count:86
# Tweet Text:Fun fact: Valencia (6) and FC Barcelona (5) are the teams to have most penalties awarded this season in La Liga.
#
# Guess whose mouth was loudest after Madrid got their RIGHT call tonight?
#
# Team on 6th &amp; respectively 9th with 17 &amp; 21 pts behind Los Blancos.
# Hashtags Used:[]
#
# Tweet 95:
# Username:Sevhic_
# Description:Bhakaniya ● Afro Tech ● General Ultra Runner ● AvGeek ● Dad ● #RunBetter ● Team @Vitality_SA Running Champion #LiveLifeWithVitality
# Location:Troll Research Airfield
# Following Count:5044
# Follower Count:6906
# Total Tweets:260213
# Retweet Count:3
# Tweet Text:📸 Was a privilege to shoot this athlete when he ran in Sa last year. A diamond in the rough, runs 26:57 over 10km on the road today in Valencia. 6th fastest time ever https://t.co/OXVyGFnU6l
# Hashtags Used:[]
#
# Tweet 96:
# Username:Bubo_Sport
# Description:Entertainment in Football
# Location:
# Following Count:9
# Follower Count:16
# Total Tweets:22
# Retweet Count:0
# Tweet Text:Karim Benzema scored his 300th &amp; 301st goal for Real Madrid against Valencia last night.
#
# Benz blazing⚡️ https://t.co/bd7jVsVKwz
# Hashtags Used:[]
#
# Tweet 97:
# Username:Mo_Asm_Jay
# Description:Diehard English Premier League &  Man Utd Fan||
# Location:In your head (Rent free)
# Following Count:366
# Follower Count:116
# Total Tweets:7602
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 98:
# Username:AlexWilson_1996
# Description:
# Location:
# Following Count:52
# Follower Count:23
# Total Tweets:31
# Retweet Count:3
# Tweet Text:As it's David Silva's birthday here's a great picture of him with David Villa at Valencia 🦇 https://t.co/2AXTrhrMjE
# Hashtags Used:[]
#
# Tweet 99:
# Username:AmaninhoCrepino
# Description:BARCELONA THE MORE INCREDIBLE TEAM IN HISTORY.
# MESSI THE GREATEST STRIKER (AND PLAYER) IN HISTORY.
# WILL BE BACK SOON TO KICK SOME ASS.
# FOLLOW FOR GOOD TWEET 😎
# Location:
# Following Count:470
# Follower Count:429
# Total Tweets:1557
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
#
# Tweet 100:
# Username:themanbundu
# Description:Saxophonist...🎷
# Keyboardist...🎹
# Musician...🎼
# Aries...👑
# Forex Enthusiast📉
# Jesus culture over pop culture...🎚
# Instagram @themanbundu
# Location:Owerri, Nigeria
# Following Count:1219
# Follower Count:588
# Total Tweets:29568
# Retweet Count:143
# Tweet Text:Valencia and Pique had some words for Real Madrid 👀 https://t.co/4XNjQYAAeH
# Hashtags Used:[]
# Scraping has completed!

# %%
listaordenada.sort()
print(listaordenada)
# Out:
# []
